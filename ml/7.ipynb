# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan)
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])


model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age'))
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛

# %%
print(model.get_cpds('chol'))
# Out:
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛

# %%
print(model.get_cpds('sex'))
# Out:
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ exang, sex | fbs)
# (age _|_ thalach, chol, restecg | exang, heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (age _|_ thalach, chol, restecg | sex, heartdisease)
# (age _|_ exang | sex, fbs)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ thalach, chol, restecg | heartdisease, fbs)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ thalach, chol, restecg | exang, trestbps, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | exang, trestbps, fbs)
# (age _|_ thalach, chol, restecg | exang, sex, heartdisease)
# (age _|_ thalach, restecg | exang, chol, heartdisease)
# (age _|_ chol, restecg | exang, thalach, heartdisease)
# (age _|_ thalach, chol, restecg | exang, heartdisease, fbs)
# (age _|_ thalach, chol | exang, heartdisease, restecg)
# (age _|_ thalach, chol, restecg | trestbps, sex, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, sex, fbs)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease)
# (age _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease, fbs)
# (age _|_ thalach, chol | trestbps, heartdisease, restecg)
# (age _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (age _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (age _|_ thalach, restecg | sex, chol, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease)
# (age _|_ thalach, chol, restecg | sex, heartdisease, fbs)
# (age _|_ thalach, chol | sex, heartdisease, restecg)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease, fbs)
# (age _|_ thalach | chol, heartdisease, restecg)
# (age _|_ chol, restecg | thalach, heartdisease, fbs)
# (age _|_ chol | thalach, heartdisease, restecg)
# (age _|_ thalach, chol | heartdisease, fbs, restecg)
# (age _|_ thalach, chol, restecg | exang, trestbps, sex, heartdisease)
# (age _|_ restecg, thalach, chol, heartdisease | exang, trestbps, sex, fbs)
# (age _|_ thalach, restecg | exang, trestbps, chol, heartdisease)
# (age _|_ thalach, heartdisease, restecg | exang, trestbps, chol, fbs)
# (age _|_ chol, restecg | exang, trestbps, thalach, heartdisease)
# (age _|_ thalach, chol, restecg | exang, trestbps, heartdisease, fbs)
# (age _|_ thalach, chol | exang, trestbps, heartdisease, restecg)
# (age _|_ chol, heartdisease, restecg | exang, trestbps, thalach, fbs)
# (age _|_ thalach, chol, heartdisease | exang, trestbps, fbs, restecg)
# (age _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (age _|_ chol, restecg | exang, thalach, sex, heartdisease)
# (age _|_ thalach, chol, restecg | exang, sex, heartdisease, fbs)
# (age _|_ thalach, chol | exang, sex, heartdisease, restecg)
# (age _|_ restecg | exang, thalach, chol, heartdisease)
# (age _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (age _|_ thalach | exang, chol, heartdisease, restecg)
# (age _|_ chol, restecg | exang, thalach, heartdisease, fbs)
# (age _|_ chol | exang, thalach, heartdisease, restecg)
# (age _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (age _|_ thalach, restecg | trestbps, sex, chol, heartdisease)
# (age _|_ thalach, heartdisease, restecg | trestbps, sex, chol, fbs)
# (age _|_ chol, restecg | trestbps, sex, thalach, heartdisease)
# (age _|_ thalach, chol, restecg | trestbps, sex, heartdisease, fbs)
# (age _|_ thalach, chol | trestbps, sex, heartdisease, restecg)
# (age _|_ chol, heartdisease, restecg | trestbps, sex, thalach, fbs)
# (age _|_ thalach, chol, heartdisease | trestbps, sex, fbs, restecg)
# (age _|_ restecg | trestbps, chol, thalach, heartdisease)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (age _|_ thalach | trestbps, chol, heartdisease, restecg)
# (age _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (age _|_ thalach, heartdisease | trestbps, chol, fbs, restecg)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (age _|_ chol | trestbps, thalach, heartdisease, restecg)
# (age _|_ thalach, chol | trestbps, heartdisease, fbs, restecg)
# (age _|_ chol, heartdisease | trestbps, thalach, fbs, restecg)
# (age _|_ restecg | thalach, sex, chol, heartdisease)
# (age _|_ thalach, restecg | sex, chol, fbs, heartdisease)
# (age _|_ thalach | restecg, sex, chol, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease, fbs)
# (age _|_ chol | thalach, sex, heartdisease, restecg)
# (age _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (age _|_ restecg | thalach, chol, heartdisease, fbs)
# (age _|_ thalach | chol, heartdisease, fbs, restecg)
# (age _|_ chol | thalach, heartdisease, fbs, restecg)
# (age _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease)
# (age _|_ thalach, heartdisease, restecg | exang, trestbps, sex, chol, fbs)
# (age _|_ chol, restecg | exang, trestbps, sex, heartdisease, thalach)
# (age _|_ thalach, chol, restecg | exang, trestbps, sex, heartdisease, fbs)
# (age _|_ thalach, chol | exang, trestbps, sex, heartdisease, restecg)
# (age _|_ chol, heartdisease, restecg | exang, trestbps, sex, thalach, fbs)
# (age _|_ thalach, chol, heartdisease | exang, trestbps, sex, fbs, restecg)
# (age _|_ restecg | exang, trestbps, chol, heartdisease, thalach)
# (age _|_ thalach, restecg | exang, trestbps, chol, heartdisease, fbs)
# (age _|_ thalach | exang, trestbps, chol, heartdisease, restecg)
# (age _|_ heartdisease, restecg | exang, trestbps, chol, thalach, fbs)
# (age _|_ thalach, heartdisease | exang, trestbps, chol, fbs, restecg)
# (age _|_ chol, restecg | exang, trestbps, heartdisease, thalach, fbs)
# (age _|_ chol | exang, trestbps, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | exang, trestbps, heartdisease, fbs, restecg)
# (age _|_ chol, heartdisease | exang, trestbps, thalach, fbs, restecg)
# (age _|_ restecg | exang, sex, chol, heartdisease, thalach)
# (age _|_ thalach, restecg | exang, sex, chol, heartdisease, fbs)
# (age _|_ thalach | exang, sex, chol, heartdisease, restecg)
# (age _|_ chol, restecg | exang, sex, heartdisease, thalach, fbs)
# (age _|_ chol | exang, sex, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | exang, sex, heartdisease, fbs, restecg)
# (age _|_ restecg | exang, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | exang, chol, heartdisease, fbs, restecg)
# (age _|_ chol | exang, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | trestbps, sex, chol, heartdisease, thalach)
# (age _|_ thalach, restecg | trestbps, sex, chol, heartdisease, fbs)
# (age _|_ thalach | trestbps, sex, chol, heartdisease, restecg)
# (age _|_ heartdisease, restecg | trestbps, sex, chol, thalach, fbs)
# (age _|_ thalach, heartdisease | trestbps, sex, chol, fbs, restecg)
# (age _|_ chol, restecg | trestbps, sex, heartdisease, thalach, fbs)
# (age _|_ chol | trestbps, sex, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | trestbps, sex, heartdisease, fbs, restecg)
# (age _|_ chol, heartdisease | trestbps, sex, thalach, fbs, restecg)
# (age _|_ restecg | trestbps, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | trestbps, chol, heartdisease, fbs, restecg)
# (age _|_ heartdisease | trestbps, chol, thalach, fbs, restecg)
# (age _|_ chol | trestbps, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | sex, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | sex, chol, heartdisease, fbs, restecg)
# (age _|_ chol | sex, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | exang, trestbps, sex, chol, heartdisease, thalach)
# (age _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease, fbs)
# (age _|_ thalach | exang, trestbps, sex, chol, heartdisease, restecg)
# (age _|_ heartdisease, restecg | exang, trestbps, sex, chol, thalach, fbs)
# (age _|_ thalach, heartdisease | exang, trestbps, sex, chol, fbs, restecg)
# (age _|_ chol, restecg | exang, trestbps, sex, heartdisease, thalach, fbs)
# (age _|_ chol | exang, trestbps, sex, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | exang, trestbps, sex, heartdisease, fbs, restecg)
# (age _|_ chol, heartdisease | exang, trestbps, sex, thalach, fbs, restecg)
# (age _|_ restecg | exang, trestbps, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | exang, trestbps, chol, heartdisease, fbs, restecg)
# (age _|_ heartdisease | exang, trestbps, chol, thalach, fbs, restecg)
# (age _|_ chol | exang, trestbps, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | exang, sex, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | exang, sex, chol, heartdisease, fbs, restecg)
# (age _|_ chol | exang, sex, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | trestbps, sex, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | trestbps, sex, chol, heartdisease, fbs, restecg)
# (age _|_ heartdisease | trestbps, sex, chol, thalach, fbs, restecg)
# (age _|_ chol | trestbps, sex, heartdisease, thalach, fbs, restecg)
# (age _|_ restecg | exang, trestbps, sex, chol, heartdisease, thalach, fbs)
# (age _|_ thalach | exang, trestbps, sex, chol, heartdisease, fbs, restecg)
# (age _|_ heartdisease | exang, trestbps, sex, chol, thalach, fbs, restecg)
# (age _|_ chol | exang, trestbps, sex, heartdisease, thalach, fbs, restecg)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | heartdisease, fbs)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | exang, sex, heartdisease)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, exang, heartdisease)
# (trestbps _|_ chol, restecg | exang, thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, fbs)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | sex, chol, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, sex, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease)
# (trestbps _|_ thalach, chol, restecg | sex, heartdisease, fbs)
# (trestbps _|_ thalach, chol | sex, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | age, chol, heartdisease)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, fbs)
# (trestbps _|_ thalach | chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | age, thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, heartdisease, fbs)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg)
# (trestbps _|_ chol, restecg | thalach, heartdisease, fbs)
# (trestbps _|_ chol | thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol | heartdisease, fbs, restecg)
# (trestbps _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, exang, sex, heartdisease)
# (trestbps _|_ chol, restecg | exang, thalach, sex, heartdisease)
# (trestbps _|_ thalach, chol, restecg | exang, sex, heartdisease, fbs)
# (trestbps _|_ thalach, chol | exang, sex, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | age, exang, chol, heartdisease)
# (trestbps _|_ restecg | exang, thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach | exang, chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | age, exang, thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, exang, heartdisease, fbs)
# (trestbps _|_ thalach, chol | age, exang, heartdisease, restecg)
# (trestbps _|_ chol, restecg | exang, thalach, heartdisease, fbs)
# (trestbps _|_ chol | exang, thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (trestbps _|_ thalach, restecg | age, sex, chol, heartdisease)
# (trestbps _|_ restecg | thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach, restecg | sex, chol, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, sex, chol, heartdisease)
# (trestbps _|_ chol, restecg | age, thalach, sex, heartdisease)
# (trestbps _|_ thalach, chol, restecg | age, sex, heartdisease, fbs)
# (trestbps _|_ thalach, chol | age, sex, heartdisease, restecg)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease, fbs)
# (trestbps _|_ chol | thalach, sex, heartdisease, restecg)
# (trestbps _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (trestbps _|_ restecg | age, thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | age, chol, heartdisease, fbs)
# (trestbps _|_ thalach | age, chol, heartdisease, restecg)
# (trestbps _|_ restecg | thalach, chol, heartdisease, fbs)
# (trestbps _|_ thalach | chol, heartdisease, fbs, restecg)
# (trestbps _|_ chol, restecg | age, thalach, heartdisease, fbs)
# (trestbps _|_ chol | age, thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (trestbps _|_ chol | thalach, heartdisease, fbs, restecg)
# (trestbps _|_ thalach, restecg | exang, sex, chol, heartdisease, age)
# (trestbps _|_ restecg | exang, sex, chol, heartdisease, thalach)
# (trestbps _|_ thalach, restecg | exang, sex, chol, heartdisease, fbs)
# (trestbps _|_ thalach | exang, sex, chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | exang, sex, heartdisease, age, thalach)
# (trestbps _|_ thalach, chol, restecg | exang, sex, heartdisease, age, fbs)
# (trestbps _|_ thalach, chol | exang, sex, heartdisease, age, restecg)
# (trestbps _|_ chol, restecg | exang, sex, heartdisease, thalach, fbs)
# (trestbps _|_ chol | exang, sex, heartdisease, thalach, restecg)
# (trestbps _|_ thalach, chol | exang, sex, heartdisease, fbs, restecg)
# (trestbps _|_ restecg | exang, chol, heartdisease, age, thalach)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, age, fbs)
# (trestbps _|_ thalach | exang, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | exang, chol, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | exang, chol, heartdisease, fbs, restecg)
# (trestbps _|_ chol, restecg | exang, heartdisease, age, thalach, fbs)
# (trestbps _|_ chol | exang, heartdisease, age, thalach, restecg)
# (trestbps _|_ thalach, chol | exang, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | exang, heartdisease, thalach, fbs, restecg)
# (trestbps _|_ restecg | sex, chol, heartdisease, age, thalach)
# (trestbps _|_ thalach, restecg | sex, chol, heartdisease, age, fbs)
# (trestbps _|_ thalach | sex, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | sex, chol, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | sex, chol, heartdisease, fbs, restecg)
# (trestbps _|_ chol, restecg | sex, heartdisease, age, thalach, fbs)
# (trestbps _|_ chol | sex, heartdisease, age, thalach, restecg)
# (trestbps _|_ thalach, chol | sex, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | sex, heartdisease, thalach, fbs, restecg)
# (trestbps _|_ restecg | chol, heartdisease, age, thalach, fbs)
# (trestbps _|_ thalach | chol, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | heartdisease, age, thalach, fbs, restecg)
# (trestbps _|_ restecg | exang, sex, chol, heartdisease, age, thalach)
# (trestbps _|_ thalach, restecg | exang, sex, chol, heartdisease, age, fbs)
# (trestbps _|_ thalach | exang, sex, chol, heartdisease, age, restecg)
# (trestbps _|_ restecg | exang, sex, chol, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | exang, sex, chol, heartdisease, fbs, restecg)
# (trestbps _|_ chol, restecg | exang, sex, heartdisease, age, thalach, fbs)
# (trestbps _|_ chol | exang, sex, heartdisease, age, thalach, restecg)
# (trestbps _|_ thalach, chol | exang, sex, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | exang, sex, heartdisease, thalach, fbs, restecg)
# (trestbps _|_ restecg | exang, chol, heartdisease, age, thalach, fbs)
# (trestbps _|_ thalach | exang, chol, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | exang, heartdisease, age, thalach, fbs, restecg)
# (trestbps _|_ restecg | sex, chol, heartdisease, age, thalach, fbs)
# (trestbps _|_ thalach | sex, chol, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | sex, heartdisease, age, thalach, fbs, restecg)
# (trestbps _|_ restecg | exang, sex, chol, heartdisease, age, thalach, fbs)
# (trestbps _|_ thalach | exang, sex, chol, heartdisease, age, fbs, restecg)
# (trestbps _|_ chol | exang, sex, heartdisease, age, thalach, fbs, restecg)
# (fbs _|_ exang, sex)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ exang, trestbps, sex | age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ thalach, chol, restecg | sex, heartdisease)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ thalach, chol, restecg | age, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | exang, trestbps, heartdisease)
# (fbs _|_ sex | age, exang, trestbps)
# (fbs _|_ thalach, chol, restecg | exang, sex, heartdisease)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease)
# (fbs _|_ thalach, chol, restecg | age, exang, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, heartdisease)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | trestbps, sex, heartdisease)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease)
# (fbs _|_ exang, sex | age, trestbps, chol)
# (fbs _|_ exang, chol, thalach, sex, restecg | age, trestbps, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease)
# (fbs _|_ thalach, chol | trestbps, heartdisease, restecg)
# (fbs _|_ exang, sex | age, trestbps, thalach)
# (fbs _|_ exang, sex | age, trestbps, restecg)
# (fbs _|_ thalach, restecg | sex, chol, heartdisease)
# (fbs _|_ thalach, chol, restecg | age, sex, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease)
# (fbs _|_ thalach, chol | sex, heartdisease, restecg)
# (fbs _|_ thalach, restecg | age, chol, heartdisease)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ thalach | chol, heartdisease, restecg)
# (fbs _|_ chol, restecg | age, thalach, heartdisease)
# (fbs _|_ thalach, chol | age, heartdisease, restecg)
# (fbs _|_ chol | thalach, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | exang, trestbps, sex, heartdisease)
# (fbs _|_ thalach, restecg | exang, trestbps, chol, heartdisease)
# (fbs _|_ sex | age, exang, trestbps, chol)
# (fbs _|_ thalach, sex, chol, restecg | age, exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | exang, trestbps, thalach, heartdisease)
# (fbs _|_ thalach, chol | exang, trestbps, heartdisease, restecg)
# (fbs _|_ sex | age, exang, trestbps, thalach)
# (fbs _|_ sex | age, exang, trestbps, restecg)
# (fbs _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (fbs _|_ thalach, chol, restecg | age, exang, sex, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, sex, heartdisease)
# (fbs _|_ thalach, chol | exang, sex, heartdisease, restecg)
# (fbs _|_ thalach, restecg | age, exang, chol, heartdisease)
# (fbs _|_ restecg | exang, thalach, chol, heartdisease)
# (fbs _|_ thalach | exang, chol, heartdisease, restecg)
# (fbs _|_ chol, restecg | age, exang, thalach, heartdisease)
# (fbs _|_ thalach, chol | age, exang, heartdisease, restecg)
# (fbs _|_ chol | exang, thalach, heartdisease, restecg)
# (fbs _|_ thalach, restecg | trestbps, sex, chol, heartdisease)
# (fbs _|_ exang | age, trestbps, sex, chol)
# (fbs _|_ exang, thalach, chol, restecg | age, trestbps, sex, heartdisease)
# (fbs _|_ chol, restecg | trestbps, sex, thalach, heartdisease)
# (fbs _|_ thalach, chol | trestbps, sex, heartdisease, restecg)
# (fbs _|_ exang | age, trestbps, sex, thalach)
# (fbs _|_ exang | age, trestbps, sex, restecg)
# (fbs _|_ exang, thalach, sex, restecg | age, trestbps, chol, heartdisease)
# (fbs _|_ restecg | trestbps, chol, thalach, heartdisease)
# (fbs _|_ thalach | trestbps, chol, heartdisease, restecg)
# (fbs _|_ exang, sex | age, trestbps, chol, thalach)
# (fbs _|_ exang, sex | age, trestbps, chol, restecg)
# (fbs _|_ exang, sex, chol, restecg | age, trestbps, thalach, heartdisease)
# (fbs _|_ exang, thalach, sex, chol | age, trestbps, heartdisease, restecg)
# (fbs _|_ chol | trestbps, thalach, heartdisease, restecg)
# (fbs _|_ exang, sex | age, trestbps, thalach, restecg)
# (fbs _|_ thalach, restecg | age, sex, chol, heartdisease)
# (fbs _|_ restecg | thalach, sex, chol, heartdisease)
# (fbs _|_ thalach | restecg, sex, chol, heartdisease)
# (fbs _|_ chol, restecg | age, thalach, sex, heartdisease)
# (fbs _|_ thalach, chol | age, sex, heartdisease, restecg)
# (fbs _|_ chol | thalach, sex, heartdisease, restecg)
# (fbs _|_ restecg | age, thalach, chol, heartdisease)
# (fbs _|_ thalach | age, chol, heartdisease, restecg)
# (fbs _|_ chol | age, thalach, heartdisease, restecg)
# (fbs _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach, chol, restecg | exang, trestbps, sex, heartdisease, age)
# (fbs _|_ chol, restecg | exang, trestbps, sex, heartdisease, thalach)
# (fbs _|_ thalach, chol | exang, trestbps, sex, heartdisease, restecg)
# (fbs _|_ thalach, sex, restecg | exang, trestbps, chol, heartdisease, age)
# (fbs _|_ restecg | exang, trestbps, chol, heartdisease, thalach)
# (fbs _|_ thalach | exang, trestbps, chol, heartdisease, restecg)
# (fbs _|_ sex | exang, trestbps, chol, age, thalach)
# (fbs _|_ sex | exang, trestbps, chol, age, restecg)
# (fbs _|_ sex, chol, restecg | exang, trestbps, heartdisease, age, thalach)
# (fbs _|_ thalach, sex, chol | exang, trestbps, heartdisease, age, restecg)
# (fbs _|_ chol | exang, trestbps, heartdisease, thalach, restecg)
# (fbs _|_ sex | exang, trestbps, age, thalach, restecg)
# (fbs _|_ thalach, restecg | exang, sex, chol, heartdisease, age)
# (fbs _|_ restecg | exang, sex, chol, heartdisease, thalach)
# (fbs _|_ thalach | exang, sex, chol, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, sex, heartdisease, age, thalach)
# (fbs _|_ thalach, chol | exang, sex, heartdisease, age, restecg)
# (fbs _|_ chol | exang, sex, heartdisease, thalach, restecg)
# (fbs _|_ restecg | exang, chol, heartdisease, age, thalach)
# (fbs _|_ thalach | exang, chol, heartdisease, age, restecg)
# (fbs _|_ chol | exang, heartdisease, age, thalach, restecg)
# (fbs _|_ exang, thalach, restecg | trestbps, sex, chol, heartdisease, age)
# (fbs _|_ restecg | trestbps, sex, chol, heartdisease, thalach)
# (fbs _|_ thalach | trestbps, sex, chol, heartdisease, restecg)
# (fbs _|_ exang | trestbps, sex, chol, age, thalach)
# (fbs _|_ exang | trestbps, sex, chol, age, restecg)
# (fbs _|_ exang, chol, restecg | trestbps, sex, heartdisease, age, thalach)
# (fbs _|_ exang, thalach, chol | trestbps, sex, heartdisease, age, restecg)
# (fbs _|_ chol | trestbps, sex, heartdisease, thalach, restecg)
# (fbs _|_ exang | trestbps, sex, age, thalach, restecg)
# (fbs _|_ exang, sex, restecg | trestbps, chol, heartdisease, age, thalach)
# (fbs _|_ exang, thalach, sex | trestbps, chol, heartdisease, age, restecg)
# (fbs _|_ exang, sex | trestbps, chol, age, thalach, restecg)
# (fbs _|_ exang, sex, chol | trestbps, heartdisease, age, thalach, restecg)
# (fbs _|_ restecg | sex, chol, heartdisease, age, thalach)
# (fbs _|_ thalach | sex, chol, heartdisease, age, restecg)
# (fbs _|_ chol | sex, heartdisease, age, thalach, restecg)
# (fbs _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease, age)
# (fbs _|_ restecg | exang, trestbps, sex, chol, heartdisease, thalach)
# (fbs _|_ thalach | exang, trestbps, sex, chol, heartdisease, restecg)
# (fbs _|_ chol, restecg | exang, trestbps, sex, heartdisease, age, thalach)
# (fbs _|_ thalach, chol | exang, trestbps, sex, heartdisease, age, restecg)
# (fbs _|_ chol | exang, trestbps, sex, heartdisease, thalach, restecg)
# (fbs _|_ sex, restecg | exang, trestbps, chol, heartdisease, age, thalach)
# (fbs _|_ thalach, sex | exang, trestbps, chol, heartdisease, age, restecg)
# (fbs _|_ sex | exang, trestbps, chol, age, thalach, restecg)
# (fbs _|_ sex, chol | exang, trestbps, heartdisease, age, thalach, restecg)
# (fbs _|_ restecg | exang, sex, chol, heartdisease, age, thalach)
# (fbs _|_ thalach | exang, sex, chol, heartdisease, age, restecg)
# (fbs _|_ chol | exang, sex, heartdisease, age, thalach, restecg)
# (fbs _|_ exang, restecg | trestbps, sex, chol, heartdisease, age, thalach)
# (fbs _|_ exang, thalach | trestbps, sex, chol, heartdisease, age, restecg)
# (fbs _|_ exang | trestbps, sex, chol, age, thalach, restecg)
# (fbs _|_ exang, chol | trestbps, sex, heartdisease, age, thalach, restecg)
# (fbs _|_ exang, sex | trestbps, chol, heartdisease, age, thalach, restecg)
# (fbs _|_ restecg | exang, trestbps, sex, chol, heartdisease, age, thalach)
# (fbs _|_ thalach | exang, trestbps, sex, chol, heartdisease, age, restecg)
# (fbs _|_ chol | exang, trestbps, sex, heartdisease, age, thalach, restecg)
# (fbs _|_ sex | exang, trestbps, chol, heartdisease, age, thalach, restecg)
# (fbs _|_ exang | trestbps, sex, chol, heartdisease, age, thalach, restecg)
# (sex _|_ age, exang, fbs)
# (sex _|_ age, fbs | exang)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, exang | fbs)
# (sex _|_ thalach, chol, restecg | exang, heartdisease)
# (sex _|_ fbs | age, exang)
# (sex _|_ age | exang, fbs)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease)
# (sex _|_ chol, heartdisease, thalach, fbs, restecg | age, trestbps)
# (sex _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ thalach, chol, restecg | age, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | heartdisease, fbs)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ exang | age, fbs)
# (sex _|_ thalach, chol, restecg | exang, trestbps, heartdisease)
# (sex _|_ chol, heartdisease, thalach, fbs, restecg | age, exang, trestbps)
# (sex _|_ thalach, chol, heartdisease, restecg | exang, trestbps, fbs)
# (sex _|_ thalach, restecg | exang, chol, heartdisease)
# (sex _|_ thalach, chol, restecg | age, exang, heartdisease)
# (sex _|_ chol, restecg | exang, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | exang, heartdisease, fbs)
# (sex _|_ thalach, chol | exang, heartdisease, restecg)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease)
# (sex _|_ thalach, heartdisease, fbs, restecg | age, trestbps, chol)
# (sex _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (sex _|_ thalach, chol, fbs, restecg | age, trestbps, heartdisease)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease, fbs)
# (sex _|_ thalach, chol | trestbps, heartdisease, restecg)
# (sex _|_ chol, heartdisease, fbs, restecg | age, trestbps, thalach)
# (sex _|_ thalach, chol, heartdisease, restecg | age, trestbps, fbs)
# (sex _|_ thalach, chol, heartdisease, fbs | age, trestbps, restecg)
# (sex _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (sex _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (sex _|_ thalach, restecg | age, chol, heartdisease)
# (sex _|_ restecg | thalach, chol, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease, fbs)
# (sex _|_ thalach | chol, heartdisease, restecg)
# (sex _|_ chol, restecg | age, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | age, heartdisease, fbs)
# (sex _|_ thalach, chol | age, heartdisease, restecg)
# (sex _|_ chol, restecg | thalach, heartdisease, fbs)
# (sex _|_ chol | thalach, heartdisease, restecg)
# (sex _|_ thalach, chol | heartdisease, fbs, restecg)
# (sex _|_ thalach, restecg | exang, trestbps, chol, heartdisease)
# (sex _|_ thalach, heartdisease, fbs, restecg | age, exang, trestbps, chol)
# (sex _|_ thalach, heartdisease, restecg | exang, trestbps, chol, fbs)
# (sex _|_ thalach, chol, fbs, restecg | age, exang, trestbps, heartdisease)
# (sex _|_ chol, restecg | exang, trestbps, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | exang, trestbps, heartdisease, fbs)
# (sex _|_ thalach, chol | exang, trestbps, heartdisease, restecg)
# (sex _|_ chol, heartdisease, fbs, restecg | age, exang, trestbps, thalach)
# (sex _|_ restecg, thalach, chol, heartdisease | age, exang, trestbps, fbs)
# (sex _|_ thalach, chol, fbs, heartdisease | age, exang, trestbps, restecg)
# (sex _|_ chol, heartdisease, restecg | exang, trestbps, thalach, fbs)
# (sex _|_ thalach, chol, heartdisease | exang, trestbps, fbs, restecg)
# (sex _|_ thalach, restecg | age, exang, chol, heartdisease)
# (sex _|_ restecg | exang, thalach, chol, heartdisease)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (sex _|_ thalach | exang, chol, heartdisease, restecg)
# (sex _|_ chol, restecg | age, exang, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | age, exang, heartdisease, fbs)
# (sex _|_ thalach, chol | age, exang, heartdisease, restecg)
# (sex _|_ chol, restecg | exang, thalach, heartdisease, fbs)
# (sex _|_ chol | exang, thalach, heartdisease, restecg)
# (sex _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (sex _|_ thalach, fbs, restecg | age, trestbps, chol, heartdisease)
# (sex _|_ restecg | trestbps, chol, thalach, heartdisease)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (sex _|_ thalach | trestbps, chol, heartdisease, restecg)
# (sex _|_ heartdisease, fbs, restecg | age, trestbps, chol, thalach)
# (sex _|_ thalach, heartdisease, restecg | age, trestbps, chol, fbs)
# (sex _|_ thalach, heartdisease, fbs | age, trestbps, chol, restecg)
# (sex _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (sex _|_ thalach, heartdisease | trestbps, chol, fbs, restecg)
# (sex _|_ chol, fbs, restecg | age, trestbps, thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | age, trestbps, heartdisease, fbs)
# (sex _|_ thalach, chol, fbs | age, trestbps, heartdisease, restecg)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (sex _|_ chol | trestbps, thalach, heartdisease, restecg)
# (sex _|_ thalach, chol | trestbps, heartdisease, fbs, restecg)
# (sex _|_ chol, heartdisease, restecg | age, trestbps, thalach, fbs)
# (sex _|_ chol, heartdisease, fbs | age, trestbps, thalach, restecg)
# (sex _|_ thalach, chol, heartdisease | age, trestbps, fbs, restecg)
# (sex _|_ chol, heartdisease | trestbps, thalach, fbs, restecg)
# (sex _|_ restecg | age, thalach, chol, heartdisease)
# (sex _|_ thalach, restecg | age, chol, heartdisease, fbs)
# (sex _|_ thalach | age, chol, heartdisease, restecg)
# (sex _|_ restecg | thalach, chol, heartdisease, fbs)
# (sex _|_ thalach | chol, heartdisease, fbs, restecg)
# (sex _|_ chol, restecg | age, thalach, heartdisease, fbs)
# (sex _|_ chol | age, thalach, heartdisease, restecg)
# (sex _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (sex _|_ chol | thalach, heartdisease, fbs, restecg)
# (sex _|_ thalach, fbs, restecg | exang, trestbps, chol, heartdisease, age)
# (sex _|_ restecg | exang, trestbps, chol, heartdisease, thalach)
# (sex _|_ thalach, restecg | exang, trestbps, chol, heartdisease, fbs)
# (sex _|_ thalach | exang, trestbps, chol, heartdisease, restecg)
# (sex _|_ heartdisease, fbs, restecg | exang, trestbps, chol, age, thalach)
# (sex _|_ thalach, heartdisease, restecg | exang, trestbps, chol, age, fbs)
# (sex _|_ thalach, heartdisease, fbs | exang, trestbps, chol, age, restecg)
# (sex _|_ heartdisease, restecg | exang, trestbps, chol, thalach, fbs)
# (sex _|_ thalach, heartdisease | exang, trestbps, chol, fbs, restecg)
# (sex _|_ chol, fbs, restecg | exang, trestbps, heartdisease, age, thalach)
# (sex _|_ thalach, chol, restecg | exang, trestbps, heartdisease, age, fbs)
# (sex _|_ thalach, chol, fbs | exang, trestbps, heartdisease, age, restecg)
# (sex _|_ chol, restecg | exang, trestbps, heartdisease, thalach, fbs)
# (sex _|_ chol | exang, trestbps, heartdisease, thalach, restecg)
# (sex _|_ thalach, chol | exang, trestbps, heartdisease, fbs, restecg)
# (sex _|_ chol, heartdisease, restecg | exang, trestbps, age, thalach, fbs)
# (sex _|_ chol, heartdisease, fbs | exang, trestbps, age, thalach, restecg)
# (sex _|_ thalach, chol, heartdisease | exang, trestbps, age, fbs, restecg)
# (sex _|_ chol, heartdisease | exang, trestbps, thalach, fbs, restecg)
# (sex _|_ restecg | exang, chol, heartdisease, age, thalach)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, age, fbs)
# (sex _|_ thalach | exang, chol, heartdisease, age, restecg)
# (sex _|_ restecg | exang, chol, heartdisease, thalach, fbs)
# (sex _|_ thalach | exang, chol, heartdisease, fbs, restecg)
# (sex _|_ chol, restecg | exang, heartdisease, age, thalach, fbs)
# (sex _|_ chol | exang, heartdisease, age, thalach, restecg)
# (sex _|_ thalach, chol | exang, heartdisease, age, fbs, restecg)
# (sex _|_ chol | exang, heartdisease, thalach, fbs, restecg)
# (sex _|_ fbs, restecg | trestbps, chol, heartdisease, age, thalach)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease, age, fbs)
# (sex _|_ thalach, fbs | trestbps, chol, heartdisease, age, restecg)
# (sex _|_ restecg | trestbps, chol, heartdisease, thalach, fbs)
# (sex _|_ thalach | trestbps, chol, heartdisease, fbs, restecg)
# (sex _|_ heartdisease, restecg | trestbps, chol, age, thalach, fbs)
# (sex _|_ heartdisease, fbs | trestbps, chol, age, thalach, restecg)
# (sex _|_ thalach, heartdisease | trestbps, chol, age, fbs, restecg)
# (sex _|_ heartdisease | trestbps, chol, thalach, fbs, restecg)
# (sex _|_ chol, restecg | trestbps, heartdisease, age, thalach, fbs)
# (sex _|_ chol, fbs | trestbps, heartdisease, age, thalach, restecg)
# (sex _|_ thalach, chol | trestbps, heartdisease, age, fbs, restecg)
# (sex _|_ chol | trestbps, heartdisease, thalach, fbs, restecg)
# (sex _|_ chol, heartdisease | trestbps, age, thalach, fbs, restecg)
# (sex _|_ restecg | chol, heartdisease, age, thalach, fbs)
# (sex _|_ thalach | chol, heartdisease, age, fbs, restecg)
# (sex _|_ chol | heartdisease, age, thalach, fbs, restecg)
# (sex _|_ fbs, restecg | exang, trestbps, chol, heartdisease, age, thalach)
# (sex _|_ thalach, restecg | exang, trestbps, chol, heartdisease, age, fbs)
# (sex _|_ thalach, fbs | exang, trestbps, chol, heartdisease, age, restecg)
# (sex _|_ restecg | exang, trestbps, chol, heartdisease, thalach, fbs)
# (sex _|_ thalach | exang, trestbps, chol, heartdisease, fbs, restecg)
# (sex _|_ heartdisease, restecg | exang, trestbps, chol, age, thalach, fbs)
# (sex _|_ heartdisease, fbs | exang, trestbps, chol, age, thalach, restecg)
# (sex _|_ thalach, heartdisease | exang, trestbps, chol, age, fbs, restecg)
# (sex _|_ heartdisease | exang, trestbps, chol, thalach, fbs, restecg)
# (sex _|_ chol, restecg | exang, trestbps, heartdisease, age, thalach, fbs)
# (sex _|_ chol, fbs | exang, trestbps, heartdisease, age, thalach, restecg)
# (sex _|_ thalach, chol | exang, trestbps, heartdisease, age, fbs, restecg)
# (sex _|_ chol | exang, trestbps, heartdisease, thalach, fbs, restecg)
# (sex _|_ chol, heartdisease | exang, trestbps, age, thalach, fbs, restecg)
# (sex _|_ restecg | exang, chol, heartdisease, age, thalach, fbs)
# (sex _|_ thalach | exang, chol, heartdisease, age, fbs, restecg)
# (sex _|_ chol | exang, heartdisease, age, thalach, fbs, restecg)
# (sex _|_ restecg | trestbps, chol, heartdisease, age, thalach, fbs)
# (sex _|_ fbs | trestbps, chol, heartdisease, age, thalach, restecg)
# (sex _|_ thalach | trestbps, chol, heartdisease, age, fbs, restecg)
# (sex _|_ heartdisease | trestbps, chol, age, thalach, fbs, restecg)
# (sex _|_ chol | trestbps, heartdisease, age, thalach, fbs, restecg)
# (sex _|_ restecg | exang, trestbps, chol, heartdisease, age, thalach, fbs)
# (sex _|_ fbs | exang, trestbps, chol, heartdisease, age, thalach, restecg)
# (sex _|_ thalach | exang, trestbps, chol, heartdisease, age, fbs, restecg)
# (sex _|_ heartdisease | exang, trestbps, chol, age, thalach, fbs, restecg)
# (sex _|_ chol | exang, trestbps, heartdisease, age, thalach, fbs, restecg)
# (exang _|_ age, sex, fbs)
# (exang _|_ age, fbs | sex)
# (exang _|_ thalach, chol, restecg | heartdisease)
# (exang _|_ sex, fbs | age)
# (exang _|_ age, sex | fbs)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease)
# (exang _|_ chol, heartdisease, thalach, fbs, restecg | age, trestbps)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (exang _|_ thalach, chol, restecg | sex, heartdisease)
# (exang _|_ fbs | age, sex)
# (exang _|_ age | sex, fbs)
# (exang _|_ thalach, restecg | chol, heartdisease)
# (exang _|_ thalach, chol, restecg | age, heartdisease)
# (exang _|_ chol, restecg | thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | heartdisease, fbs)
# (exang _|_ thalach, chol | heartdisease, restecg)
# (exang _|_ sex | age, fbs)
# (exang _|_ thalach, chol, restecg | trestbps, sex, heartdisease)
# (exang _|_ chol, heartdisease, thalach, fbs, restecg | age, trestbps, sex)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, sex, fbs)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease)
# (exang _|_ thalach, heartdisease, fbs, restecg | age, trestbps, chol)
# (exang _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (exang _|_ thalach, chol, fbs, restecg | age, trestbps, heartdisease)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease, fbs)
# (exang _|_ thalach, chol | trestbps, heartdisease, restecg)
# (exang _|_ chol, heartdisease, fbs, restecg | age, trestbps, thalach)
# (exang _|_ thalach, chol, heartdisease, restecg | age, trestbps, fbs)
# (exang _|_ thalach, chol, heartdisease, fbs | age, trestbps, restecg)
# (exang _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (exang _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (exang _|_ thalach, restecg | sex, chol, heartdisease)
# (exang _|_ thalach, chol, restecg | age, sex, heartdisease)
# (exang _|_ chol, restecg | thalach, sex, heartdisease)
# (exang _|_ thalach, chol, restecg | sex, heartdisease, fbs)
# (exang _|_ thalach, chol | sex, heartdisease, restecg)
# (exang _|_ thalach, restecg | age, chol, heartdisease)
# (exang _|_ restecg | thalach, chol, heartdisease)
# (exang _|_ thalach, restecg | chol, heartdisease, fbs)
# (exang _|_ thalach | chol, heartdisease, restecg)
# (exang _|_ chol, restecg | age, thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | age, heartdisease, fbs)
# (exang _|_ thalach, chol | age, heartdisease, restecg)
# (exang _|_ chol, restecg | thalach, heartdisease, fbs)
# (exang _|_ chol | thalach, heartdisease, restecg)
# (exang _|_ thalach, chol | heartdisease, fbs, restecg)
# (exang _|_ thalach, restecg | trestbps, sex, chol, heartdisease)
# (exang _|_ thalach, heartdisease, fbs, restecg | age, trestbps, sex, chol)
# (exang _|_ thalach, heartdisease, restecg | trestbps, sex, chol, fbs)
# (exang _|_ thalach, chol, fbs, restecg | age, trestbps, sex, heartdisease)
# (exang _|_ chol, restecg | trestbps, sex, thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | trestbps, sex, heartdisease, fbs)
# (exang _|_ thalach, chol | trestbps, sex, heartdisease, restecg)
# (exang _|_ chol, heartdisease, fbs, restecg | age, trestbps, sex, thalach)
# (exang _|_ restecg, thalach, chol, heartdisease | age, trestbps, sex, fbs)
# (exang _|_ thalach, chol, fbs, heartdisease | age, trestbps, sex, restecg)
# (exang _|_ chol, heartdisease, restecg | trestbps, sex, thalach, fbs)
# (exang _|_ thalach, chol, heartdisease | trestbps, sex, fbs, restecg)
# (exang _|_ thalach, fbs, restecg | age, trestbps, chol, heartdisease)
# (exang _|_ restecg | trestbps, chol, thalach, heartdisease)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (exang _|_ thalach | trestbps, chol, heartdisease, restecg)
# (exang _|_ heartdisease, fbs, restecg | age, trestbps, chol, thalach)
# (exang _|_ thalach, heartdisease, restecg | age, trestbps, chol, fbs)
# (exang _|_ thalach, heartdisease, fbs | age, trestbps, chol, restecg)
# (exang _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (exang _|_ thalach, heartdisease | trestbps, chol, fbs, restecg)
# (exang _|_ chol, fbs, restecg | age, trestbps, thalach, heartdisease)
# (exang _|_ thalach, chol, restecg | age, trestbps, heartdisease, fbs)
# (exang _|_ thalach, chol, fbs | age, trestbps, heartdisease, restecg)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (exang _|_ chol | trestbps, thalach, heartdisease, restecg)
# (exang _|_ thalach, chol | trestbps, heartdisease, fbs, restecg)
# (exang _|_ chol, heartdisease, restecg | age, trestbps, thalach, fbs)
# (exang _|_ chol, heartdisease, fbs | age, trestbps, thalach, restecg)
# (exang _|_ thalach, chol, heartdisease | age, trestbps, fbs, restecg)
# (exang _|_ chol, heartdisease | trestbps, thalach, fbs, restecg)
# (exang _|_ thalach, restecg | age, sex, chol, heartdisease)
# (exang _|_ restecg | thalach, sex, chol, heartdisease)
# (exang _|_ thalach, restecg | sex, chol, fbs, heartdisease)
# (exang _|_ thalach | restecg, sex, chol, heartdisease)
# (exang _|_ chol, restecg | age, thalach, sex, heartdisease)
# (exang _|_ thalach, chol, restecg | age, sex, heartdisease, fbs)
# (exang _|_ thalach, chol | age, sex, heartdisease, restecg)
# (exang _|_ chol, restecg | thalach, sex, heartdisease, fbs)
# (exang _|_ chol | thalach, sex, heartdisease, restecg)
# (exang _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (exang _|_ restecg | age, thalach, chol, heartdisease)
# (exang _|_ thalach, restecg | age, chol, heartdisease, fbs)
# (exang _|_ thalach | age, chol, heartdisease, restecg)
# (exang _|_ restecg | thalach, chol, heartdisease, fbs)
# (exang _|_ thalach | chol, heartdisease, fbs, restecg)
# (exang _|_ chol, restecg | age, thalach, heartdisease, fbs)
# (exang _|_ chol | age, thalach, heartdisease, restecg)
# (exang _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (exang _|_ chol | thalach, heartdisease, fbs, restecg)
# (exang _|_ thalach, fbs, restecg | trestbps, sex, chol, heartdisease, age)
# (exang _|_ restecg | trestbps, sex, chol, heartdisease, thalach)
# (exang _|_ thalach, restecg | trestbps, sex, chol, heartdisease, fbs)
# (exang _|_ thalach | trestbps, sex, chol, heartdisease, restecg)
# (exang _|_ heartdisease, fbs, restecg | trestbps, sex, chol, age, thalach)
# (exang _|_ thalach, heartdisease, restecg | trestbps, sex, chol, age, fbs)
# (exang _|_ thalach, heartdisease, fbs | trestbps, sex, chol, age, restecg)
# (exang _|_ heartdisease, restecg | trestbps, sex, chol, thalach, fbs)
# (exang _|_ thalach, heartdisease | trestbps, sex, chol, fbs, restecg)
# (exang _|_ chol, fbs, restecg | trestbps, sex, heartdisease, age, thalach)
# (exang _|_ thalach, chol, restecg | trestbps, sex, heartdisease, age, fbs)
# (exang _|_ thalach, chol, fbs | trestbps, sex, heartdisease, age, restecg)
# (exang _|_ chol, restecg | trestbps, sex, heartdisease, thalach, fbs)
# (exang _|_ chol | trestbps, sex, heartdisease, thalach, restecg)
# (exang _|_ thalach, chol | trestbps, sex, heartdisease, fbs, restecg)
# (exang _|_ chol, heartdisease, restecg | trestbps, sex, age, thalach, fbs)
# (exang _|_ chol, heartdisease, fbs | trestbps, sex, age, thalach, restecg)
# (exang _|_ thalach, chol, heartdisease | trestbps, sex, age, fbs, restecg)
# (exang _|_ chol, heartdisease | trestbps, sex, thalach, fbs, restecg)
# (exang _|_ fbs, restecg | trestbps, chol, heartdisease, age, thalach)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease, age, fbs)
# (exang _|_ thalach, fbs | trestbps, chol, heartdisease, age, restecg)
# (exang _|_ restecg | trestbps, chol, heartdisease, thalach, fbs)
# (exang _|_ thalach | trestbps, chol, heartdisease, fbs, restecg)
# (exang _|_ heartdisease, restecg | trestbps, chol, age, thalach, fbs)
# (exang _|_ heartdisease, fbs | trestbps, chol, age, thalach, restecg)
# (exang _|_ thalach, heartdisease | trestbps, chol, age, fbs, restecg)
# (exang _|_ heartdisease | trestbps, chol, thalach, fbs, restecg)
# (exang _|_ chol, restecg | trestbps, heartdisease, age, thalach, fbs)
# (exang _|_ chol, fbs | trestbps, heartdisease, age, thalach, restecg)
# (exang _|_ thalach, chol | trestbps, heartdisease, age, fbs, restecg)
# (exang _|_ chol | trestbps, heartdisease, thalach, fbs, restecg)
# (exang _|_ chol, heartdisease | trestbps, age, thalach, fbs, restecg)
# (exang _|_ restecg | sex, chol, heartdisease, age, thalach)
# (exang _|_ thalach, restecg | sex, chol, heartdisease, age, fbs)
# (exang _|_ thalach | sex, chol, heartdisease, age, restecg)
# (exang _|_ restecg | sex, chol, heartdisease, thalach, fbs)
# (exang _|_ thalach | sex, chol, heartdisease, fbs, restecg)
# (exang _|_ chol, restecg | sex, heartdisease, age, thalach, fbs)
# (exang _|_ chol | sex, heartdisease, age, thalach, restecg)
# (exang _|_ thalach, chol | sex, heartdisease, age, fbs, restecg)
# (exang _|_ chol | sex, heartdisease, thalach, fbs, restecg)
# (exang _|_ restecg | chol, heartdisease, age, thalach, fbs)
# (exang _|_ thalach | chol, heartdisease, age, fbs, restecg)
# (exang _|_ chol | heartdisease, age, thalach, fbs, restecg)
# (exang _|_ fbs, restecg | trestbps, sex, chol, heartdisease, age, thalach)
# (exang _|_ thalach, restecg | trestbps, sex, chol, heartdisease, age, fbs)
# (exang _|_ thalach, fbs | trestbps, sex, chol, heartdisease, age, restecg)
# (exang _|_ restecg | trestbps, sex, chol, heartdisease, thalach, fbs)
# (exang _|_ thalach | trestbps, sex, chol, heartdisease, fbs, restecg)
# (exang _|_ heartdisease, restecg | trestbps, sex, chol, age, thalach, fbs)
# (exang _|_ heartdisease, fbs | trestbps, sex, chol, age, thalach, restecg)
# (exang _|_ thalach, heartdisease | trestbps, sex, chol, age, fbs, restecg)
# (exang _|_ heartdisease | trestbps, sex, chol, thalach, fbs, restecg)
# (exang _|_ chol, restecg | trestbps, sex, heartdisease, age, thalach, fbs)
# (exang _|_ chol, fbs | trestbps, sex, heartdisease, age, thalach, restecg)
# (exang _|_ thalach, chol | trestbps, sex, heartdisease, age, fbs, restecg)
# (exang _|_ chol | trestbps, sex, heartdisease, thalach, fbs, restecg)
# (exang _|_ chol, heartdisease | trestbps, sex, age, thalach, fbs, restecg)
# (exang _|_ restecg | trestbps, chol, heartdisease, age, thalach, fbs)
# (exang _|_ fbs | trestbps, chol, heartdisease, age, thalach, restecg)
# (exang _|_ thalach | trestbps, chol, heartdisease, age, fbs, restecg)
# (exang _|_ heartdisease | trestbps, chol, age, thalach, fbs, restecg)
# (exang _|_ chol | trestbps, heartdisease, age, thalach, fbs, restecg)
# (exang _|_ restecg | sex, chol, heartdisease, age, thalach, fbs)
# (exang _|_ thalach | sex, chol, heartdisease, age, fbs, restecg)
# (exang _|_ chol | sex, heartdisease, age, thalach, fbs, restecg)
# (exang _|_ restecg | trestbps, sex, chol, heartdisease, age, thalach, fbs)
# (exang _|_ fbs | trestbps, sex, chol, heartdisease, age, thalach, restecg)
# (exang _|_ thalach | trestbps, sex, chol, heartdisease, age, fbs, restecg)
# (exang _|_ heartdisease | trestbps, sex, chol, age, thalach, fbs, restecg)
# (exang _|_ chol | trestbps, sex, heartdisease, age, thalach, fbs, restecg)
# (heartdisease _|_ exang, sex | age, trestbps)
# (heartdisease _|_ age, exang, sex | trestbps, fbs)
# (heartdisease _|_ sex | age, exang, trestbps)
# (heartdisease _|_ age, sex | exang, trestbps, fbs)
# (heartdisease _|_ exang | age, trestbps, sex)
# (heartdisease _|_ age, exang | trestbps, sex, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, chol)
# (heartdisease _|_ age, exang, sex | trestbps, chol, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, thalach)
# (heartdisease _|_ exang, sex | age, trestbps, fbs)
# (heartdisease _|_ exang, sex | age, trestbps, restecg)
# (heartdisease _|_ age, exang, sex | trestbps, thalach, fbs)
# (heartdisease _|_ age, exang, sex | trestbps, fbs, restecg)
# (heartdisease _|_ age | exang, trestbps, sex, fbs)
# (heartdisease _|_ sex | age, exang, trestbps, chol)
# (heartdisease _|_ age, sex | exang, trestbps, chol, fbs)
# (heartdisease _|_ sex | age, exang, trestbps, thalach)
# (heartdisease _|_ sex | age, exang, trestbps, fbs)
# (heartdisease _|_ sex | age, exang, trestbps, restecg)
# (heartdisease _|_ age, sex | exang, trestbps, thalach, fbs)
# (heartdisease _|_ age, sex | exang, trestbps, fbs, restecg)
# (heartdisease _|_ exang | age, trestbps, sex, chol)
# (heartdisease _|_ age, exang | trestbps, sex, chol, fbs)
# (heartdisease _|_ exang | age, trestbps, sex, thalach)
# (heartdisease _|_ exang | age, trestbps, sex, fbs)
# ...
# (thalach _|_ trestbps, fbs, restecg | exang, sex, chol, heartdisease, age)
# (thalach _|_ age, trestbps, restecg | exang, sex, chol, heartdisease, fbs)
# (thalach _|_ age, trestbps, fbs | exang, sex, chol, heartdisease, restecg)
# (thalach _|_ trestbps, chol, restecg | exang, sex, heartdisease, age, fbs)
# (thalach _|_ trestbps, chol, fbs | exang, sex, heartdisease, age, restecg)
# (thalach _|_ age, trestbps, chol | exang, sex, heartdisease, fbs, restecg)
# (thalach _|_ trestbps, sex, restecg | exang, chol, heartdisease, age, fbs)
# (thalach _|_ trestbps, sex, fbs | exang, chol, heartdisease, age, restecg)
# (thalach _|_ age, trestbps, sex | exang, chol, heartdisease, fbs, restecg)
# (thalach _|_ trestbps, sex, chol | exang, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, fbs, restecg | trestbps, sex, chol, heartdisease, age)
# (thalach _|_ age, exang, restecg | trestbps, sex, chol, heartdisease, fbs)
# (thalach _|_ age, exang, fbs | trestbps, sex, chol, heartdisease, restecg)
# (thalach _|_ exang | trestbps, sex, chol, age, fbs)
# (thalach _|_ exang | trestbps, sex, chol, age, restecg)
# (thalach _|_ age, exang | trestbps, sex, chol, fbs, restecg)
# (thalach _|_ exang, chol, restecg | trestbps, sex, heartdisease, age, fbs)
# (thalach _|_ exang, chol, fbs | trestbps, sex, heartdisease, age, restecg)
# (thalach _|_ age, exang, chol | trestbps, sex, heartdisease, fbs, restecg)
# (thalach _|_ exang | trestbps, sex, age, fbs, restecg)
# (thalach _|_ exang, sex, restecg | trestbps, chol, heartdisease, age, fbs)
# (thalach _|_ exang, sex, fbs | trestbps, chol, heartdisease, age, restecg)
# (thalach _|_ age, exang, sex | trestbps, chol, heartdisease, fbs, restecg)
# (thalach _|_ exang, sex | trestbps, chol, age, fbs, restecg)
# (thalach _|_ exang, sex, chol | trestbps, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, trestbps, restecg | sex, chol, heartdisease, age, fbs)
# (thalach _|_ exang, trestbps, fbs | sex, chol, heartdisease, age, restecg)
# (thalach _|_ age, exang, trestbps | sex, chol, heartdisease, fbs, restecg)
# (thalach _|_ exang, trestbps, chol | sex, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, trestbps, sex | chol, heartdisease, age, fbs, restecg)
# (thalach _|_ fbs, restecg | exang, trestbps, sex, chol, heartdisease, age)
# (thalach _|_ age, restecg | exang, trestbps, sex, chol, heartdisease, fbs)
# (thalach _|_ age, fbs | exang, trestbps, sex, chol, heartdisease, restecg)
# (thalach _|_ age | exang, trestbps, sex, chol, fbs, restecg)
# (thalach _|_ chol, restecg | exang, trestbps, sex, heartdisease, age, fbs)
# (thalach _|_ chol, fbs | exang, trestbps, sex, heartdisease, age, restecg)
# (thalach _|_ age, chol | exang, trestbps, sex, heartdisease, fbs, restecg)
# (thalach _|_ sex, restecg | exang, trestbps, chol, heartdisease, age, fbs)
# (thalach _|_ sex, fbs | exang, trestbps, chol, heartdisease, age, restecg)
# (thalach _|_ age, sex | exang, trestbps, chol, heartdisease, fbs, restecg)
# (thalach _|_ sex | exang, trestbps, chol, age, fbs, restecg)
# (thalach _|_ sex, chol | exang, trestbps, heartdisease, age, fbs, restecg)
# (thalach _|_ trestbps, restecg | exang, sex, chol, heartdisease, age, fbs)
# (thalach _|_ trestbps, fbs | exang, sex, chol, heartdisease, age, restecg)
# (thalach _|_ age, trestbps | exang, sex, chol, heartdisease, fbs, restecg)
# (thalach _|_ trestbps, chol | exang, sex, heartdisease, age, fbs, restecg)
# (thalach _|_ trestbps, sex | exang, chol, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, restecg | trestbps, sex, chol, heartdisease, age, fbs)
# (thalach _|_ exang, fbs | trestbps, sex, chol, heartdisease, age, restecg)
# (thalach _|_ age, exang | trestbps, sex, chol, heartdisease, fbs, restecg)
# (thalach _|_ exang | trestbps, sex, chol, age, fbs, restecg)
# (thalach _|_ exang, chol | trestbps, sex, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, sex | trestbps, chol, heartdisease, age, fbs, restecg)
# (thalach _|_ exang, trestbps | sex, chol, heartdisease, age, fbs, restecg)
# (thalach _|_ restecg | exang, trestbps, sex, chol, heartdisease, age, fbs)
# (thalach _|_ fbs | exang, trestbps, sex, chol, heartdisease, age, restecg)
# (thalach _|_ age | exang, trestbps, sex, chol, heartdisease, fbs, restecg)
# (thalach _|_ chol | exang, trestbps, sex, heartdisease, age, fbs, restecg)
# (thalach _|_ sex | exang, trestbps, chol, heartdisease, age, fbs, restecg)
# (thalach _|_ trestbps | exang, sex, chol, heartdisease, age, fbs, restecg)
# (thalach _|_ exang | trestbps, sex, chol, heartdisease, age, fbs, restecg)
# (chol _|_ exang, age, trestbps, sex, thalach, fbs, restecg | heartdisease)
# (chol _|_ age, trestbps, sex, thalach, fbs, restecg | exang, heartdisease)
# (chol _|_ exang, age, thalach, sex, fbs, restecg | trestbps, heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ age, exang, sex | trestbps, fbs)
# (chol _|_ exang, age, trestbps, thalach, fbs, restecg | sex, heartdisease)
# (chol _|_ exang, trestbps, sex, thalach, fbs, restecg | age, heartdisease)
# (chol _|_ exang, age, trestbps, sex, fbs, restecg | thalach, heartdisease)
# (chol _|_ exang, age, trestbps, sex, thalach, restecg | heartdisease, fbs)
# (chol _|_ exang, age, trestbps, sex, thalach, fbs | heartdisease, restecg)
# (chol _|_ age, thalach, sex, fbs, restecg | exang, trestbps, heartdisease)
# (chol _|_ sex | age, exang, trestbps)
# (chol _|_ age, sex | exang, trestbps, fbs)
# (chol _|_ age, trestbps, thalach, fbs, restecg | exang, sex, heartdisease)
# (chol _|_ trestbps, sex, thalach, fbs, restecg | age, exang, heartdisease)
# (chol _|_ age, trestbps, sex, fbs, restecg | exang, thalach, heartdisease)
# (chol _|_ age, trestbps, sex, thalach, restecg | exang, heartdisease, fbs)
# (chol _|_ age, trestbps, sex, thalach, fbs | exang, heartdisease, restecg)
# (chol _|_ exang, age, thalach, fbs, restecg | trestbps, sex, heartdisease)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ age, exang | trestbps, sex, fbs)
# (chol _|_ exang, thalach, sex, fbs, restecg | age, trestbps, heartdisease)
# (chol _|_ exang, age, sex, fbs, restecg | trestbps, thalach, heartdisease)
# (chol _|_ exang, age, thalach, sex, restecg | trestbps, heartdisease, fbs)
# (chol _|_ exang, age, thalach, sex, fbs | trestbps, heartdisease, restecg)
# (chol _|_ exang, sex | age, trestbps, thalach)
# (chol _|_ exang, sex | age, trestbps, fbs)
# (chol _|_ exang, sex | age, trestbps, restecg)
# (chol _|_ age, exang, sex | trestbps, thalach, fbs)
# (chol _|_ age, exang, sex | trestbps, fbs, restecg)
# (chol _|_ exang, trestbps, thalach, fbs, restecg | age, sex, heartdisease)
# (chol _|_ exang, age, trestbps, fbs, restecg | thalach, sex, heartdisease)
# (chol _|_ exang, age, trestbps, thalach, restecg | sex, heartdisease, fbs)
# (chol _|_ exang, age, trestbps, thalach, fbs | sex, heartdisease, restecg)
# (chol _|_ exang, trestbps, sex, fbs, restecg | age, thalach, heartdisease)
# (chol _|_ exang, trestbps, sex, thalach, restecg | age, heartdisease, fbs)
# (chol _|_ exang, trestbps, sex, thalach, fbs | age, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, sex, restecg | thalach, heartdisease, fbs)
# (chol _|_ exang, age, trestbps, sex, fbs | thalach, heartdisease, restecg)
# (chol _|_ exang, age, trestbps, sex, thalach | heartdisease, fbs, restecg)
# (chol _|_ age, thalach, fbs, restecg | exang, trestbps, sex, heartdisease)
# (chol _|_ age | exang, trestbps, sex, fbs)
# (chol _|_ thalach, sex, fbs, restecg | age, exang, trestbps, heartdisease)
# (chol _|_ age, sex, fbs, restecg | exang, trestbps, thalach, heartdisease)
# (chol _|_ age, thalach, sex, restecg | exang, trestbps, heartdisease, fbs)
# (chol _|_ age, thalach, sex, fbs | exang, trestbps, heartdisease, restecg)
# (chol _|_ sex | age, exang, trestbps, thalach)
# (chol _|_ sex | age, exang, trestbps, fbs)
# (chol _|_ sex | age, exang, trestbps, restecg)
# (chol _|_ age, sex | exang, trestbps, thalach, fbs)
# (chol _|_ age, sex | exang, trestbps, fbs, restecg)
# (chol _|_ trestbps, thalach, fbs, restecg | age, exang, sex, heartdisease)
# (chol _|_ age, trestbps, fbs, restecg | exang, thalach, sex, heartdisease)
# (chol _|_ age, trestbps, thalach, restecg | exang, sex, heartdisease, fbs)
# (chol _|_ age, trestbps, thalach, fbs | exang, sex, heartdisease, restecg)
# (chol _|_ trestbps, sex, fbs, restecg | age, exang, thalach, heartdisease)
# (chol _|_ trestbps, sex, thalach, restecg | age, exang, heartdisease, fbs)
# (chol _|_ trestbps, sex, thalach, fbs | age, exang, heartdisease, restecg)
# (chol _|_ age, trestbps, sex, restecg | exang, thalach, heartdisease, fbs)
# (chol _|_ age, trestbps, sex, fbs | exang, thalach, heartdisease, restecg)
# (chol _|_ age, trestbps, sex, thalach | exang, heartdisease, fbs, restecg)
# (chol _|_ exang, thalach, fbs, restecg | age, trestbps, sex, heartdisease)
# (chol _|_ age, exang, fbs, restecg | trestbps, sex, thalach, heartdisease)
# (chol _|_ age, exang, thalach, restecg | trestbps, sex, heartdisease, fbs)
# (chol _|_ age, exang, thalach, fbs | trestbps, sex, heartdisease, restecg)
# (chol _|_ exang | age, trestbps, sex, thalach)
# (chol _|_ exang | age, trestbps, sex, fbs)
# (chol _|_ exang | age, trestbps, sex, restecg)
# (chol _|_ age, exang | trestbps, sex, thalach, fbs)
# (chol _|_ age, exang | trestbps, sex, fbs, restecg)
# (chol _|_ exang, sex, fbs, restecg | age, trestbps, thalach, heartdisease)
# (chol _|_ exang, thalach, sex, restecg | age, trestbps, heartdisease, fbs)
# (chol _|_ exang, thalach, sex, fbs | age, trestbps, heartdisease, restecg)
# (chol _|_ age, exang, sex, restecg | trestbps, thalach, heartdisease, fbs)
# (chol _|_ age, exang, sex, fbs | trestbps, thalach, heartdisease, restecg)
# (chol _|_ age, exang, thalach, sex | trestbps, heartdisease, fbs, restecg)
# (chol _|_ exang, sex | age, trestbps, thalach, fbs)
# (chol _|_ exang, sex | age, trestbps, thalach, restecg)
# (chol _|_ exang, sex | age, trestbps, fbs, restecg)
# (chol _|_ age, exang, sex | trestbps, thalach, fbs, restecg)
# (chol _|_ exang, trestbps, fbs, restecg | age, thalach, sex, heartdisease)
# (chol _|_ exang, trestbps, thalach, restecg | age, sex, heartdisease, fbs)
# (chol _|_ exang, trestbps, thalach, fbs | age, sex, heartdisease, restecg)
# (chol _|_ age, exang, trestbps, restecg | thalach, sex, heartdisease, fbs)
# (chol _|_ age, exang, trestbps, fbs | thalach, sex, heartdisease, restecg)
# (chol _|_ age, exang, trestbps, thalach | sex, heartdisease, fbs, restecg)
# (chol _|_ exang, trestbps, sex, restecg | age, thalach, heartdisease, fbs)
# (chol _|_ exang, trestbps, sex, fbs | age, thalach, heartdisease, restecg)
# (chol _|_ exang, trestbps, sex, thalach | age, heartdisease, fbs, restecg)
# (chol _|_ age, exang, trestbps, sex | thalach, heartdisease, fbs, restecg)
# (chol _|_ thalach, fbs, restecg | exang, trestbps, sex, heartdisease, age)
# (chol _|_ age, fbs, restecg | exang, trestbps, sex, heartdisease, thalach)
# (chol _|_ age, thalach, restecg | exang, trestbps, sex, heartdisease, fbs)
# (chol _|_ age, thalach, fbs | exang, trestbps, sex, heartdisease, restecg)
# (chol _|_ age | exang, trestbps, sex, thalach, fbs)
# (chol _|_ age | exang, trestbps, sex, fbs, restecg)
# (chol _|_ sex, fbs, restecg | exang, trestbps, heartdisease, age, thalach)
# (chol _|_ thalach, sex, restecg | exang, trestbps, heartdisease, age, fbs)
# (chol _|_ thalach, sex, fbs | exang, trestbps, heartdisease, age, restecg)
# (chol _|_ age, sex, restecg | exang, trestbps, heartdisease, thalach, fbs)
# (chol _|_ age, sex, fbs | exang, trestbps, heartdisease, thalach, restecg)
# (chol _|_ age, thalach, sex | exang, trestbps, heartdisease, fbs, restecg)
# (chol _|_ sex | exang, trestbps, age, thalach, fbs)
# (chol _|_ sex | exang, trestbps, age, thalach, restecg)
# (chol _|_ sex | exang, trestbps, age, fbs, restecg)
# (chol _|_ age, sex | exang, trestbps, thalach, fbs, restecg)
# (chol _|_ trestbps, fbs, restecg | exang, sex, heartdisease, age, thalach)
# (chol _|_ trestbps, thalach, restecg | exang, sex, heartdisease, age, fbs)
# (chol _|_ trestbps, thalach, fbs | exang, sex, heartdisease, age, restecg)
# (chol _|_ age, trestbps, restecg | exang, sex, heartdisease, thalach, fbs)
# (chol _|_ age, trestbps, fbs | exang, sex, heartdisease, thalach, restecg)
# (chol _|_ age, trestbps, thalach | exang, sex, heartdisease, fbs, restecg)
# (chol _|_ trestbps, sex, restecg | exang, heartdisease, age, thalach, fbs)
# (chol _|_ trestbps, sex, fbs | exang, heartdisease, age, thalach, restecg)
# (chol _|_ trestbps, sex, thalach | exang, heartdisease, age, fbs, restecg)
# (chol _|_ age, trestbps, sex | exang, heartdisease, thalach, fbs, restecg)
# (chol _|_ exang, fbs, restecg | trestbps, sex, heartdisease, age, thalach)
# (chol _|_ exang, thalach, restecg | trestbps, sex, heartdisease, age, fbs)
# (chol _|_ exang, thalach, fbs | trestbps, sex, heartdisease, age, restecg)
# (chol _|_ age, exang, restecg | trestbps, sex, heartdisease, thalach, fbs)
# (chol _|_ age, exang, fbs | trestbps, sex, heartdisease, thalach, restecg)
# (chol _|_ age, exang, thalach | trestbps, sex, heartdisease, fbs, restecg)
# (chol _|_ exang | trestbps, sex, age, thalach, fbs)
# (chol _|_ exang | trestbps, sex, age, thalach, restecg)
# (chol _|_ exang | trestbps, sex, age, fbs, restecg)
# (chol _|_ age, exang | trestbps, sex, thalach, fbs, restecg)
# (chol _|_ exang, sex, restecg | trestbps, heartdisease, age, thalach, fbs)
# (chol _|_ exang, sex, fbs | trestbps, heartdisease, age, thalach, restecg)
# (chol _|_ exang, thalach, sex | trestbps, heartdisease, age, fbs, restecg)
# (chol _|_ age, exang, sex | trestbps, heartdisease, thalach, fbs, restecg)
# (chol _|_ exang, sex | trestbps, age, thalach, fbs, restecg)
# (chol _|_ exang, trestbps, restecg | sex, heartdisease, age, thalach, fbs)
# (chol _|_ exang, trestbps, fbs | sex, heartdisease, age, thalach, restecg)
# (chol _|_ exang, trestbps, thalach | sex, heartdisease, age, fbs, restecg)
# (chol _|_ age, exang, trestbps | sex, heartdisease, thalach, fbs, restecg)
# (chol _|_ exang, trestbps, sex | heartdisease, age, thalach, fbs, restecg)
# (chol _|_ fbs, restecg | exang, trestbps, sex, heartdisease, age, thalach)
# (chol _|_ thalach, restecg | exang, trestbps, sex, heartdisease, age, fbs)
# (chol _|_ thalach, fbs | exang, trestbps, sex, heartdisease, age, restecg)
# (chol _|_ age, restecg | exang, trestbps, sex, heartdisease, thalach, fbs)
# (chol _|_ age, fbs | exang, trestbps, sex, heartdisease, thalach, restecg)
# (chol _|_ age, thalach | exang, trestbps, sex, heartdisease, fbs, restecg)
# (chol _|_ age | exang, trestbps, sex, thalach, fbs, restecg)
# (chol _|_ sex, restecg | exang, trestbps, heartdisease, age, thalach, fbs)
# (chol _|_ sex, fbs | exang, trestbps, heartdisease, age, thalach, restecg)
# (chol _|_ thalach, sex | exang, trestbps, heartdisease, age, fbs, restecg)
# (chol _|_ age, sex | exang, trestbps, heartdisease, thalach, fbs, restecg)
# (chol _|_ sex | exang, trestbps, age, thalach, fbs, restecg)
# (chol _|_ trestbps, restecg | exang, sex, heartdisease, age, thalach, fbs)
# (chol _|_ trestbps, fbs | exang, sex, heartdisease, age, thalach, restecg)
# (chol _|_ trestbps, thalach | exang, sex, heartdisease, age, fbs, restecg)
# (chol _|_ age, trestbps | exang, sex, heartdisease, thalach, fbs, restecg)
# (chol _|_ trestbps, sex | exang, heartdisease, age, thalach, fbs, restecg)
# (chol _|_ exang, restecg | trestbps, sex, heartdisease, age, thalach, fbs)
# (chol _|_ exang, fbs | trestbps, sex, heartdisease, age, thalach, restecg)
# (chol _|_ exang, thalach | trestbps, sex, heartdisease, age, fbs, restecg)
# (chol _|_ age, exang | trestbps, sex, heartdisease, thalach, fbs, restecg)
# (chol _|_ exang | trestbps, sex, age, thalach, fbs, restecg)
# (chol _|_ exang, sex | trestbps, heartdisease, age, thalach, fbs, restecg)
# (chol _|_ exang, trestbps | sex, heartdisease, age, thalach, fbs, restecg)
# (chol _|_ restecg | exang, trestbps, sex, heartdisease, age, thalach, fbs)
# (chol _|_ fbs | exang, trestbps, sex, heartdisease, age, thalach, restecg)
# (chol _|_ thalach | exang, trestbps, sex, heartdisease, age, fbs, restecg)
# (chol _|_ age | exang, trestbps, sex, heartdisease, thalach, fbs, restecg)
# (chol _|_ sex | exang, trestbps, heartdisease, age, thalach, fbs, restecg)
# (chol _|_ trestbps | exang, sex, heartdisease, age, thalach, fbs, restecg)
# (chol _|_ exang | trestbps, sex, heartdisease, age, thalach, fbs, restecg)

# %%
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛
# c:\users\harshith\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]
# c:\users\harshith\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
