# %%
from pgmpy.models import BayesianModel

cancer_model = BayesianModel([('Pollution', 'Cancer'), 
                              ('Smoker', 'Cancer'),
                              ('Cancer', 'Xray'),
                              ('Cancer', 'Dyspnoea')])

# %%
cancer_model.nodes()
# Out:
# ['Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea']

# %%
cancer_model.edges()
# Out:
# [('Pollution', 'Cancer'),
#  ('Cancer', 'Xray'),
#  ('Cancer', 'Dyspnoea'),
#  ('Smoker', 'Cancer')]

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,
                      values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,
                       values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],
                                [0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'], evidence_card=[2])

# %%
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)

cancer_model.check_model()
# Out:
# True

# %%
cancer_model.is_active_trail('Pollution', 'Smoker')
# Out:
# False

# %%
cancer_model.is_active_trail('Pollution', 'Smoker', observed=['Cancer'])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x255d525ce48>,
#  <TabularCPD representing P(Smoker:2) at 0x255d525ce10>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x255d525cdd8>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x255d525ce80>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x255d525ceb8>]

# %%
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker'))
print(cancer_model.get_cpds('Xray'))
print(cancer_model.get_cpds('Dyspnoea'))
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %%
print("Local Independencies for X Ray :",cancer_model.local_independencies('Xray'))
print("Local Independencies for Pollution :",cancer_model.local_independencies('Pollution'))
print("Local Independencies for Smoker :",cancer_model.local_independencies('Smoker'))
print("Local Independencies for Dyspnoea :",cancer_model.local_independencies('Dyspnoea'))
print("Local Independencies for Cancer :",cancer_model.local_independencies('Cancer'))
# Out:
# Local Independencies for X Ray : (Xray _|_ Dyspnoea, Smoker, Pollution | Cancer)
# Local Independencies for Pollution : (Pollution _|_ Smoker)
# Local Independencies for Smoker : (Smoker _|_ Pollution)
# Local Independencies for Dyspnoea : (Dyspnoea _|_ Xray, Smoker, Pollution | Cancer)
# Local Independencies for Cancer :

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Dyspnoea, Xray | Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea, Xray | Smoker, Cancer)
# (Pollution _|_ Dyspnoea | Xray, Cancer)
# (Pollution _|_ Xray | Smoker, Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea | Smoker, Xray, Cancer)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea, Xray | Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Xray, Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Xray, Cancer, Pollution)
# (Xray _|_ Dyspnoea, Smoker, Pollution | Cancer)
# (Xray _|_ Smoker, Pollution | Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea, Pollution | Smoker, Cancer)
# (Xray _|_ Dyspnoea, Smoker | Cancer, Pollution)
# (Xray _|_ Pollution | Smoker, Dyspnoea, Cancer)
# (Xray _|_ Smoker | Dyspnoea, Cancer, Pollution)
# (Xray _|_ Dyspnoea | Smoker, Cancer, Pollution)
# (Dyspnoea _|_ Xray, Smoker, Pollution | Cancer)
# (Dyspnoea _|_ Smoker, Pollution | Xray, Cancer)
# (Dyspnoea _|_ Xray, Pollution | Smoker, Cancer)
# (Dyspnoea _|_ Xray, Smoker | Cancer, Pollution)
# (Dyspnoea _|_ Pollution | Smoker, Xray, Cancer)
# (Dyspnoea _|_ Smoker | Xray, Cancer, Pollution)
# (Dyspnoea _|_ Xray | Smoker, Cancer, Pollution)

# %%
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛
# c:\users\harshith\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan)
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])


model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age'))
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛

# %%
print(model.get_cpds('chol'))
# Out:
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛

# %%
print(model.get_cpds('sex'))
# Out:
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ exang | sex)
# (age _|_ sex | exang)
# (age _|_ thalach, restecg, chol | heartdisease)
# (age _|_ exang, sex | fbs)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ thalach, restecg, chol | heartdisease, sex)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, restecg, chol | heartdisease, exang)
# (age _|_ sex | exang, fbs)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ thalach, restecg | heartdisease, chol)
# (age _|_ thalach, restecg, chol | heartdisease, fbs)
# (age _|_ thalach, restecg, chol | heartdisease, trestbps)
# (age _|_ heartdisease, restecg, chol, thalach | fbs, trestbps)
# (age _|_ restecg, chol | heartdisease, thalach, sex)
# (age _|_ restecg, chol | heartdisease, thalach, exang)
# (age _|_ chol | heartdisease, thalach, restecg)
# (age _|_ restecg | heartdisease, thalach, chol)
# (age _|_ restecg, chol | heartdisease, thalach, fbs)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps)
# (age _|_ heartdisease, restecg, chol | thalach, fbs, trestbps)
# (age _|_ thalach, restecg, chol | heartdisease, exang, sex)
# (age _|_ thalach, chol | heartdisease, restecg, sex)
# (age _|_ thalach, restecg | heartdisease, chol, sex)
# (age _|_ thalach, restecg, chol | heartdisease, fbs, sex)
# (age _|_ thalach, restecg, chol | heartdisease, trestbps, sex)
# (age _|_ heartdisease, thalach, restecg, chol | fbs, trestbps, sex)
# (age _|_ thalach, chol | heartdisease, exang, restecg)
# (age _|_ thalach, restecg | heartdisease, exang, chol)
# (age _|_ thalach, restecg, chol | heartdisease, exang, fbs)
# (age _|_ thalach, restecg, chol | heartdisease, exang, trestbps)
# (age _|_ heartdisease, thalach, restecg, chol | exang, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, chol)
# (age _|_ thalach, chol | heartdisease, restecg, fbs)
# (age _|_ thalach, chol | heartdisease, restecg, trestbps)
# (age _|_ heartdisease, thalach, chol | restecg, fbs, trestbps)
# (age _|_ thalach, restecg | heartdisease, fbs, chol)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps)
# (age _|_ heartdisease, thalach, restecg | fbs, chol, trestbps)
# (age _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (age _|_ restecg, chol | heartdisease, thalach, exang, sex)
# (age _|_ chol | heartdisease, thalach, restecg, sex)
# (age _|_ restecg | heartdisease, thalach, chol, sex)
# (age _|_ restecg, chol | heartdisease, thalach, fbs, sex)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, sex)
# (age _|_ heartdisease, restecg, chol | thalach, fbs, trestbps, sex)
# (age _|_ chol | heartdisease, thalach, exang, restecg)
# (age _|_ restecg | heartdisease, thalach, exang, chol)
# (age _|_ restecg, chol | heartdisease, thalach, exang, fbs)
# (age _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (age _|_ heartdisease, restecg, chol | thalach, exang, fbs, trestbps)
# (age _|_ chol | heartdisease, thalach, restecg, fbs)
# (age _|_ chol | heartdisease, thalach, restecg, trestbps)
# (age _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (age _|_ restecg | heartdisease, thalach, fbs, chol)
# (age _|_ restecg | heartdisease, thalach, chol, trestbps)
# (age _|_ heartdisease, restecg | thalach, fbs, chol, trestbps)
# (age _|_ restecg, chol | heartdisease, thalach, fbs, trestbps)
# (age _|_ thalach, chol | heartdisease, exang, restecg, sex)
# (age _|_ thalach, restecg | heartdisease, exang, chol, sex)
# (age _|_ thalach, restecg, chol | heartdisease, exang, fbs, sex)
# (age _|_ thalach, restecg, chol | heartdisease, exang, trestbps, sex)
# (age _|_ heartdisease, restecg, chol, thalach | exang, fbs, trestbps, sex)
# (age _|_ thalach | heartdisease, restecg, chol, sex)
# (age _|_ thalach, chol | heartdisease, restecg, fbs, sex)
# (age _|_ thalach, chol | heartdisease, restecg, trestbps, sex)
# (age _|_ heartdisease, chol, thalach | restecg, fbs, trestbps, sex)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, sex)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, sex)
# (age _|_ heartdisease, restecg, thalach | fbs, chol, trestbps, sex)
# (age _|_ thalach, restecg, chol | heartdisease, fbs, trestbps, sex)
# (age _|_ thalach | heartdisease, exang, restecg, chol)
# (age _|_ thalach, chol | heartdisease, exang, restecg, fbs)
# (age _|_ thalach, chol | heartdisease, exang, restecg, trestbps)
# (age _|_ heartdisease, chol, thalach | exang, restecg, trestbps, fbs)
# (age _|_ thalach, restecg | heartdisease, exang, fbs, chol)
# (age _|_ thalach, restecg | heartdisease, exang, chol, trestbps)
# (age _|_ heartdisease, restecg, thalach | exang, fbs, chol, trestbps)
# (age _|_ thalach, restecg, chol | heartdisease, exang, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, fbs, chol)
# (age _|_ thalach | heartdisease, restecg, chol, trestbps)
# (age _|_ heartdisease, thalach | restecg, fbs, chol, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, fbs, trestbps)
# (age _|_ thalach, restecg | heartdisease, fbs, chol, trestbps)
# (age _|_ chol | thalach, sex, exang, restecg, heartdisease)
# (age _|_ restecg | thalach, sex, exang, chol, heartdisease)
# (age _|_ restecg, chol | thalach, sex, exang, heartdisease, fbs)
# (age _|_ restecg, chol | thalach, sex, exang, heartdisease, trestbps)
# (age _|_ heartdisease, restecg, chol | sex, exang, thalach, fbs, trestbps)
# (age _|_ chol | thalach, sex, restecg, heartdisease, fbs)
# (age _|_ chol | thalach, sex, restecg, heartdisease, trestbps)
# (age _|_ heartdisease, chol | sex, restecg, thalach, fbs, trestbps)
# (age _|_ restecg | thalach, sex, chol, heartdisease, fbs)
# (age _|_ restecg | thalach, sex, chol, heartdisease, trestbps)
# (age _|_ heartdisease, restecg | sex, chol, thalach, fbs, trestbps)
# (age _|_ restecg, chol | thalach, sex, heartdisease, fbs, trestbps)
# (age _|_ chol | thalach, exang, restecg, heartdisease, fbs)
# (age _|_ chol | thalach, exang, restecg, heartdisease, trestbps)
# (age _|_ heartdisease, chol | exang, restecg, thalach, fbs, trestbps)
# (age _|_ restecg | thalach, exang, chol, heartdisease, fbs)
# (age _|_ restecg | thalach, exang, chol, heartdisease, trestbps)
# (age _|_ heartdisease, restecg | exang, chol, thalach, fbs, trestbps)
# (age _|_ restecg, chol | thalach, exang, heartdisease, fbs, trestbps)
# (age _|_ heartdisease | restecg, chol, thalach, fbs, trestbps)
# (age _|_ chol | thalach, restecg, heartdisease, fbs, trestbps)
# (age _|_ restecg | thalach, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | sex, exang, restecg, chol, heartdisease)
# (age _|_ thalach, chol | sex, exang, restecg, heartdisease, fbs)
# (age _|_ thalach, chol | sex, exang, restecg, heartdisease, trestbps)
# (age _|_ heartdisease, chol, thalach | sex, exang, restecg, fbs, trestbps)
# (age _|_ thalach, restecg | sex, exang, chol, heartdisease, fbs)
# (age _|_ thalach, restecg | sex, exang, chol, heartdisease, trestbps)
# (age _|_ heartdisease, restecg, thalach | sex, exang, chol, fbs, trestbps)
# (age _|_ thalach, restecg, chol | sex, exang, heartdisease, fbs, trestbps)
# (age _|_ thalach | sex, restecg, chol, heartdisease, fbs)
# (age _|_ thalach | sex, restecg, chol, heartdisease, trestbps)
# (age _|_ heartdisease, thalach | sex, restecg, chol, fbs, trestbps)
# (age _|_ thalach, chol | sex, restecg, heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | sex, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | exang, restecg, chol, heartdisease, fbs)
# (age _|_ thalach | exang, restecg, chol, heartdisease, trestbps)
# (age _|_ heartdisease, thalach | exang, restecg, chol, fbs, trestbps)
# (age _|_ thalach, chol | exang, restecg, heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | exang, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | restecg, chol, heartdisease, fbs, trestbps)
# (age _|_ chol | thalach, sex, exang, restecg, heartdisease, fbs)
# (age _|_ chol | thalach, sex, exang, restecg, heartdisease, trestbps)
# (age _|_ heartdisease, chol | sex, exang, restecg, thalach, fbs, trestbps)
# (age _|_ restecg | thalach, sex, exang, chol, heartdisease, fbs)
# (age _|_ restecg | thalach, sex, exang, chol, heartdisease, trestbps)
# (age _|_ heartdisease, restecg | sex, exang, chol, thalach, fbs, trestbps)
# (age _|_ restecg, chol | thalach, sex, exang, heartdisease, fbs, trestbps)
# (age _|_ heartdisease | sex, restecg, chol, thalach, fbs, trestbps)
# (age _|_ chol | thalach, sex, restecg, heartdisease, fbs, trestbps)
# (age _|_ restecg | thalach, sex, chol, heartdisease, fbs, trestbps)
# (age _|_ heartdisease | exang, restecg, chol, thalach, fbs, trestbps)
# (age _|_ chol | thalach, exang, restecg, heartdisease, fbs, trestbps)
# (age _|_ restecg | thalach, exang, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | sex, exang, restecg, chol, heartdisease, fbs)
# (age _|_ thalach | sex, exang, restecg, chol, heartdisease, trestbps)
# (age _|_ heartdisease, thalach | sex, exang, restecg, chol, fbs, trestbps)
# (age _|_ thalach, chol | sex, exang, restecg, heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | sex, exang, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | sex, restecg, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | exang, restecg, chol, heartdisease, fbs, trestbps)
# (age _|_ heartdisease | sex, exang, restecg, chol, thalach, fbs, trestbps)
# (age _|_ chol | thalach, sex, exang, restecg, heartdisease, fbs, trestbps)
# (age _|_ restecg | thalach, sex, exang, chol, heartdisease, fbs, trestbps)
# (age _|_ thalach | sex, exang, restecg, chol, heartdisease, fbs, trestbps)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, restecg, chol | heartdisease)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ thalach, restecg, chol | heartdisease, sex)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease)
# (trestbps _|_ thalach, restecg, chol | heartdisease, exang)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, chol)
# (trestbps _|_ thalach, restecg, chol | heartdisease, fbs)
# (trestbps _|_ restecg, chol | heartdisease, thalach, sex)
# (trestbps _|_ restecg, chol | age, thalach, heartdisease)
# (trestbps _|_ restecg, chol | heartdisease, thalach, exang)
# (trestbps _|_ chol | heartdisease, thalach, restecg)
# (trestbps _|_ restecg | heartdisease, thalach, chol)
# (trestbps _|_ restecg, chol | heartdisease, thalach, fbs)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, sex)
# (trestbps _|_ thalach, restecg, chol | heartdisease, exang, sex)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex)
# (trestbps _|_ thalach, restecg | heartdisease, chol, sex)
# (trestbps _|_ thalach, restecg, chol | heartdisease, fbs, sex)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, exang)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | age, heartdisease, chol)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (trestbps _|_ thalach, chol | heartdisease, exang, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, exang, chol)
# (trestbps _|_ thalach, restecg, chol | heartdisease, exang, fbs)
# (trestbps _|_ thalach | heartdisease, restecg, chol)
# (trestbps _|_ thalach, chol | heartdisease, restecg, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol)
# (trestbps _|_ restecg, chol | age, thalach, heartdisease, sex)
# (trestbps _|_ restecg, chol | heartdisease, thalach, exang, sex)
# (trestbps _|_ chol | heartdisease, thalach, restecg, sex)
# (trestbps _|_ restecg | heartdisease, thalach, chol, sex)
# (trestbps _|_ restecg, chol | heartdisease, thalach, fbs, sex)
# (trestbps _|_ restecg, chol | age, thalach, exang, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, heartdisease)
# (trestbps _|_ restecg | age, thalach, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, fbs, heartdisease)
# (trestbps _|_ chol | heartdisease, thalach, exang, restecg)
# (trestbps _|_ restecg | heartdisease, thalach, exang, chol)
# (trestbps _|_ restecg, chol | heartdisease, thalach, exang, fbs)
# (trestbps _|_ chol | heartdisease, thalach, restecg, fbs)
# (trestbps _|_ restecg | heartdisease, thalach, fbs, chol)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, exang, sex)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg, sex)
# (trestbps _|_ thalach, restecg | age, heartdisease, chol, sex)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, fbs, sex)
# (trestbps _|_ thalach, chol | heartdisease, exang, restecg, sex)
# (trestbps _|_ thalach, restecg | heartdisease, exang, chol, sex)
# (trestbps _|_ thalach, restecg, chol | heartdisease, exang, fbs, sex)
# (trestbps _|_ thalach | heartdisease, restecg, chol, sex)
# (trestbps _|_ thalach, chol | heartdisease, restecg, fbs, sex)
# (trestbps _|_ thalach, restecg | heartdisease, fbs, chol, sex)
# (trestbps _|_ thalach, chol | age, heartdisease, exang, restecg)
# (trestbps _|_ thalach, restecg | age, heartdisease, exang, chol)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, exang, fbs)
# (trestbps _|_ thalach | age, heartdisease, restecg, chol)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg, fbs)
# (trestbps _|_ thalach, restecg | age, heartdisease, fbs, chol)
# (trestbps _|_ thalach | heartdisease, exang, restecg, chol)
# (trestbps _|_ thalach, chol | heartdisease, exang, restecg, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, exang, fbs, chol)
# (trestbps _|_ thalach | heartdisease, restecg, fbs, chol)
# (trestbps _|_ restecg, chol | sex, age, exang, heartdisease, thalach)
# (trestbps _|_ chol | sex, age, restecg, heartdisease, thalach)
# (trestbps _|_ restecg | sex, age, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | sex, age, heartdisease, thalach, fbs)
# (trestbps _|_ chol | thalach, sex, exang, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, sex, exang, chol, heartdisease)
# (trestbps _|_ restecg, chol | thalach, sex, exang, heartdisease, fbs)
# (trestbps _|_ chol | thalach, sex, restecg, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, sex, chol, heartdisease, fbs)
# (trestbps _|_ chol | age, exang, restecg, heartdisease, thalach)
# (trestbps _|_ restecg | age, exang, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ chol | age, restecg, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | age, chol, heartdisease, thalach, fbs)
# (trestbps _|_ chol | thalach, exang, restecg, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach, chol | sex, age, exang, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | sex, age, exang, chol, heartdisease)
# (trestbps _|_ thalach, restecg, chol | sex, age, exang, heartdisease, fbs)
# (trestbps _|_ thalach | sex, age, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | sex, age, restecg, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, age, chol, heartdisease, fbs)
# (trestbps _|_ thalach | sex, exang, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | sex, exang, restecg, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach | sex, restecg, chol, heartdisease, fbs)
# (trestbps _|_ thalach | age, exang, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | age, exang, restecg, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | age, exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach | age, restecg, chol, heartdisease, fbs)
# (trestbps _|_ thalach | exang, restecg, chol, heartdisease, fbs)
# (trestbps _|_ chol | sex, age, exang, restecg, heartdisease, thalach)
# (trestbps _|_ restecg | sex, age, exang, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | sex, age, exang, heartdisease, thalach, fbs)
# (trestbps _|_ chol | sex, age, restecg, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | sex, age, chol, heartdisease, thalach, fbs)
# (trestbps _|_ chol | thalach, sex, exang, restecg, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, sex, exang, chol, heartdisease, fbs)
# (trestbps _|_ chol | age, exang, restecg, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | age, exang, chol, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | sex, age, exang, restecg, chol, heartdisease)
# (trestbps _|_ thalach, chol | sex, age, exang, restecg, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, age, exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach | sex, age, restecg, chol, heartdisease, fbs)
# (trestbps _|_ thalach | sex, exang, restecg, chol, heartdisease, fbs)
# (trestbps _|_ thalach | age, exang, restecg, chol, heartdisease, fbs)
# (trestbps _|_ chol | sex, age, exang, restecg, heartdisease, thalach, fbs)
# (trestbps _|_ restecg | sex, age, exang, chol, heartdisease, thalach, fbs)
# (trestbps _|_ thalach | sex, age, exang, restecg, chol, heartdisease, fbs)
# (fbs _|_ exang, sex)
# (fbs _|_ exang | sex)
# (fbs _|_ exang, trestbps, sex | age)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, restecg, chol | heartdisease)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ thalach, restecg, chol | heartdisease, sex)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ thalach, restecg, chol | age, heartdisease)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ thalach, restecg, chol | heartdisease, exang)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ thalach, restecg | heartdisease, chol)
# (fbs _|_ thalach, restecg, chol | heartdisease, trestbps)
# (fbs _|_ restecg, chol | heartdisease, thalach, sex)
# (fbs _|_ restecg, chol | age, thalach, heartdisease)
# (fbs _|_ exang, sex | age, thalach, trestbps)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang)
# (fbs _|_ chol | heartdisease, thalach, restecg)
# (fbs _|_ restecg | heartdisease, thalach, chol)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ thalach, restecg, chol | age, heartdisease, sex)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ thalach, restecg, chol | heartdisease, exang, sex)
# (fbs _|_ thalach, chol | heartdisease, restecg, sex)
# (fbs _|_ thalach, restecg | heartdisease, chol, sex)
# (fbs _|_ thalach, restecg, chol | heartdisease, trestbps, sex)
# (fbs _|_ thalach, restecg, chol | age, heartdisease, exang)
# (fbs _|_ sex | age, exang, trestbps)
# (fbs _|_ thalach, chol | age, heartdisease, restecg)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ thalach, restecg | age, heartdisease, chol)
# (fbs _|_ exang, sex | age, chol, trestbps)
# (fbs _|_ restecg, chol, sex, thalach, exang | age, heartdisease, trestbps)
# (fbs _|_ thalach, chol | heartdisease, exang, restecg)
# (fbs _|_ thalach, restecg | heartdisease, exang, chol)
# (fbs _|_ thalach, restecg, chol | heartdisease, exang, trestbps)
# (fbs _|_ thalach | heartdisease, restecg, chol)
# (fbs _|_ thalach, chol | heartdisease, restecg, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps)
# (fbs _|_ restecg, chol | age, thalach, heartdisease, sex)
# (fbs _|_ exang | age, thalach, trestbps, sex)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang, sex)
# (fbs _|_ chol | heartdisease, thalach, restecg, sex)
# (fbs _|_ restecg | heartdisease, thalach, chol, sex)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps, sex)
# (fbs _|_ restecg, chol | age, thalach, exang, heartdisease)
# (fbs _|_ sex | age, thalach, exang, trestbps)
# (fbs _|_ chol | age, thalach, restecg, heartdisease)
# (fbs _|_ exang, sex | age, thalach, restecg, trestbps)
# (fbs _|_ restecg | age, thalach, chol, heartdisease)
# (fbs _|_ exang, sex | age, thalach, chol, trestbps)
# (fbs _|_ exang, restecg, chol, sex | age, thalach, heartdisease, trestbps)
# (fbs _|_ chol | heartdisease, thalach, exang, restecg)
# (fbs _|_ restecg | heartdisease, thalach, exang, chol)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (fbs _|_ chol | heartdisease, thalach, restecg, trestbps)
# (fbs _|_ restecg | heartdisease, thalach, chol, trestbps)
# (fbs _|_ thalach, restecg, chol | age, heartdisease, exang, sex)
# (fbs _|_ thalach, chol | age, heartdisease, restecg, sex)
# (fbs _|_ exang | age, restecg, trestbps, sex)
# (fbs _|_ thalach, restecg | age, heartdisease, chol, sex)
# (fbs _|_ exang | age, chol, trestbps, sex)
# (fbs _|_ thalach, exang, restecg, chol | age, heartdisease, trestbps, sex)
# (fbs _|_ thalach, chol | heartdisease, exang, restecg, sex)
# (fbs _|_ thalach, restecg | heartdisease, exang, chol, sex)
# (fbs _|_ thalach, restecg, chol | heartdisease, exang, trestbps, sex)
# (fbs _|_ thalach | heartdisease, restecg, chol, sex)
# (fbs _|_ thalach, chol | heartdisease, restecg, trestbps, sex)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps, sex)
# (fbs _|_ thalach, chol | age, heartdisease, exang, restecg)
# (fbs _|_ sex | age, exang, restecg, trestbps)
# (fbs _|_ thalach, restecg | age, heartdisease, exang, chol)
# (fbs _|_ sex | age, exang, chol, trestbps)
# (fbs _|_ thalach, restecg, chol, sex | age, heartdisease, exang, trestbps)
# (fbs _|_ thalach | age, heartdisease, restecg, chol)
# (fbs _|_ exang, sex | age, restecg, chol, trestbps)
# (fbs _|_ thalach, exang, chol, sex | age, heartdisease, restecg, trestbps)
# (fbs _|_ thalach, exang, restecg, sex | age, heartdisease, chol, trestbps)
# (fbs _|_ thalach | heartdisease, exang, restecg, chol)
# (fbs _|_ thalach, chol | heartdisease, exang, restecg, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, exang, chol, trestbps)
# (fbs _|_ thalach | heartdisease, restecg, chol, trestbps)
# (fbs _|_ restecg, chol | sex, age, exang, heartdisease, thalach)
# (fbs _|_ chol | sex, age, restecg, heartdisease, thalach)
# (fbs _|_ exang | sex, age, restecg, thalach, trestbps)
# (fbs _|_ restecg | sex, age, chol, heartdisease, thalach)
# (fbs _|_ exang | sex, age, chol, thalach, trestbps)
# (fbs _|_ exang, restecg, chol | sex, age, heartdisease, thalach, trestbps)
# (fbs _|_ chol | thalach, sex, exang, restecg, heartdisease)
# (fbs _|_ restecg | thalach, sex, exang, chol, heartdisease)
# (fbs _|_ restecg, chol | thalach, sex, exang, heartdisease, trestbps)
# (fbs _|_ chol | thalach, sex, restecg, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, sex, chol, heartdisease, trestbps)
# (fbs _|_ chol | age, exang, restecg, heartdisease, thalach)
# (fbs _|_ sex | age, exang, restecg, thalach, trestbps)
# (fbs _|_ restecg | age, exang, chol, heartdisease, thalach)
# (fbs _|_ sex | age, exang, chol, thalach, trestbps)
# (fbs _|_ restecg, chol, sex | age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ exang, sex | age, restecg, chol, thalach, trestbps)
# (fbs _|_ exang, chol, sex | age, restecg, heartdisease, thalach, trestbps)
# (fbs _|_ exang, restecg, sex | age, chol, heartdisease, thalach, trestbps)
# (fbs _|_ chol | thalach, exang, restecg, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, exang, chol, heartdisease, trestbps)
# (fbs _|_ thalach, chol | sex, age, exang, restecg, heartdisease)
# (fbs _|_ thalach, restecg | sex, age, exang, chol, heartdisease)
# (fbs _|_ thalach, restecg, chol | sex, age, exang, heartdisease, trestbps)
# (fbs _|_ thalach | sex, age, restecg, chol, heartdisease)
# (fbs _|_ exang | sex, age, restecg, chol, trestbps)
# (fbs _|_ thalach, exang, chol | sex, age, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, exang, restecg | sex, age, chol, heartdisease, trestbps)
# (fbs _|_ thalach | sex, exang, restecg, chol, heartdisease)
# (fbs _|_ thalach, chol | sex, exang, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | sex, exang, chol, heartdisease, trestbps)
# (fbs _|_ thalach | sex, restecg, chol, heartdisease, trestbps)
# (fbs _|_ thalach | age, exang, restecg, chol, heartdisease)
# (fbs _|_ sex | age, exang, restecg, chol, trestbps)
# (fbs _|_ thalach, chol, sex | age, exang, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg, sex | age, exang, chol, heartdisease, trestbps)
# (fbs _|_ thalach, exang, sex | age, restecg, chol, heartdisease, trestbps)
# (fbs _|_ thalach | exang, restecg, chol, heartdisease, trestbps)
# (fbs _|_ chol | sex, age, exang, restecg, heartdisease, thalach)
# (fbs _|_ restecg | sex, age, exang, chol, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, age, exang, heartdisease, thalach, trestbps)
# (fbs _|_ exang | sex, age, restecg, chol, thalach, trestbps)
# (fbs _|_ exang, chol | sex, age, restecg, heartdisease, thalach, trestbps)
# (fbs _|_ exang, restecg | sex, age, chol, heartdisease, thalach, trestbps)
# (fbs _|_ chol | thalach, sex, exang, restecg, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, sex, exang, chol, heartdisease, trestbps)
# (fbs _|_ sex | age, exang, restecg, chol, thalach, trestbps)
# (fbs _|_ chol, sex | age, exang, restecg, heartdisease, thalach, trestbps)
# (fbs _|_ restecg, sex | age, exang, chol, heartdisease, thalach, trestbps)
# (fbs _|_ exang, sex | age, restecg, chol, heartdisease, thalach, trestbps)
# (fbs _|_ thalach | sex, age, exang, restecg, chol, heartdisease)
# (fbs _|_ thalach, chol | sex, age, exang, restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | sex, age, exang, chol, heartdisease, trestbps)
# (fbs _|_ thalach, exang | sex, age, restecg, chol, heartdisease, trestbps)
# (fbs _|_ thalach | sex, exang, restecg, chol, heartdisease, trestbps)
# (fbs _|_ thalach, sex | age, exang, restecg, chol, heartdisease, trestbps)
# (fbs _|_ chol | sex, age, exang, restecg, heartdisease, thalach, trestbps)
# (fbs _|_ restecg | sex, age, exang, chol, heartdisease, thalach, trestbps)
# (fbs _|_ exang | sex, age, restecg, chol, heartdisease, thalach, trestbps)
# (fbs _|_ sex | age, exang, restecg, chol, heartdisease, thalach, trestbps)
# (fbs _|_ thalach | sex, age, exang, restecg, chol, heartdisease, trestbps)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, fbs | exang)
# (sex _|_ thalach, restecg, chol | heartdisease)
# (sex _|_ age, exang | fbs)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ fbs | age, exang)
# (sex _|_ thalach, restecg, chol | age, heartdisease)
# (sex _|_ exang | age, fbs)
# (sex _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps)
# (sex _|_ thalach, restecg, chol | heartdisease, exang)
# (sex _|_ age | exang, fbs)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ thalach, restecg | heartdisease, chol)
# (sex _|_ thalach, restecg, chol | heartdisease, fbs)
# (sex _|_ thalach, restecg, chol | heartdisease, trestbps)
# (sex _|_ heartdisease, restecg, chol, thalach | fbs, trestbps)
# (sex _|_ restecg, chol | age, thalach, heartdisease)
# (sex _|_ heartdisease, restecg, fbs, chol | age, thalach, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach, exang)
# (sex _|_ chol | heartdisease, thalach, restecg)
# (sex _|_ restecg | heartdisease, thalach, chol)
# (sex _|_ restecg, chol | heartdisease, thalach, fbs)
# (sex _|_ restecg, chol | heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, restecg, chol | thalach, fbs, trestbps)
# (sex _|_ thalach, restecg, chol | age, heartdisease, exang)
# (sex _|_ restecg, chol, heartdisease, thalach, fbs | age, exang, trestbps)
# (sex _|_ thalach, chol | age, heartdisease, restecg)
# (sex _|_ heartdisease, thalach, fbs, chol | age, restecg, trestbps)
# (sex _|_ thalach, restecg | age, heartdisease, chol)
# (sex _|_ heartdisease, thalach, restecg, fbs | age, chol, trestbps)
# (sex _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (sex _|_ thalach, restecg, fbs, chol | age, heartdisease, trestbps)
# (sex _|_ heartdisease, thalach, restecg, chol | age, fbs, trestbps)
# (sex _|_ thalach, chol | heartdisease, exang, restecg)
# (sex _|_ thalach, restecg | heartdisease, exang, chol)
# (sex _|_ thalach, restecg, chol | heartdisease, exang, fbs)
# (sex _|_ thalach, restecg, chol | heartdisease, exang, trestbps)
# (sex _|_ heartdisease, restecg, chol, thalach | exang, fbs, trestbps)
# (sex _|_ thalach | heartdisease, restecg, chol)
# (sex _|_ thalach, chol | heartdisease, restecg, fbs)
# (sex _|_ thalach, chol | heartdisease, restecg, trestbps)
# (sex _|_ heartdisease, chol, thalach | restecg, fbs, trestbps)
# (sex _|_ thalach, restecg | heartdisease, fbs, chol)
# (sex _|_ thalach, restecg | heartdisease, chol, trestbps)
# (sex _|_ heartdisease, restecg, thalach | fbs, chol, trestbps)
# (sex _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (sex _|_ restecg, chol | age, thalach, exang, heartdisease)
# (sex _|_ heartdisease, restecg, fbs, chol | age, thalach, exang, trestbps)
# (sex _|_ chol | age, thalach, restecg, heartdisease)
# (sex _|_ heartdisease, fbs, chol | age, thalach, restecg, trestbps)
# (sex _|_ restecg | age, thalach, chol, heartdisease)
# (sex _|_ heartdisease, restecg, fbs | age, thalach, chol, trestbps)
# (sex _|_ restecg, chol | age, thalach, fbs, heartdisease)
# (sex _|_ restecg, fbs, chol | age, thalach, heartdisease, trestbps)
# (sex _|_ heartdisease, restecg, chol | age, thalach, fbs, trestbps)
# (sex _|_ chol | heartdisease, thalach, exang, restecg)
# (sex _|_ restecg | heartdisease, thalach, exang, chol)
# (sex _|_ restecg, chol | heartdisease, thalach, exang, fbs)
# (sex _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (sex _|_ heartdisease, restecg, chol | thalach, exang, fbs, trestbps)
# (sex _|_ chol | heartdisease, thalach, restecg, fbs)
# (sex _|_ chol | heartdisease, thalach, restecg, trestbps)
# (sex _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (sex _|_ restecg | heartdisease, thalach, fbs, chol)
# (sex _|_ restecg | heartdisease, thalach, chol, trestbps)
# (sex _|_ heartdisease, restecg | thalach, fbs, chol, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach, fbs, trestbps)
# (sex _|_ thalach, chol | age, heartdisease, exang, restecg)
# (sex _|_ heartdisease, fbs, chol, thalach | age, exang, restecg, trestbps)
# (sex _|_ thalach, restecg | age, heartdisease, exang, chol)
# (sex _|_ heartdisease, restecg, fbs, thalach | age, exang, chol, trestbps)
# (sex _|_ thalach, restecg, chol | age, heartdisease, exang, fbs)
# (sex _|_ thalach, restecg, fbs, chol | age, heartdisease, exang, trestbps)
# (sex _|_ heartdisease, restecg, chol, thalach | age, exang, fbs, trestbps)
# (sex _|_ thalach | age, heartdisease, restecg, chol)
# (sex _|_ heartdisease, fbs, thalach | age, restecg, chol, trestbps)
# (sex _|_ thalach, chol | age, heartdisease, restecg, fbs)
# (sex _|_ thalach, fbs, chol | age, heartdisease, restecg, trestbps)
# (sex _|_ heartdisease, chol, thalach | age, restecg, fbs, trestbps)
# (sex _|_ thalach, restecg | age, heartdisease, fbs, chol)
# (sex _|_ thalach, restecg, fbs | age, heartdisease, chol, trestbps)
# (sex _|_ heartdisease, restecg, thalach | age, fbs, chol, trestbps)
# (sex _|_ thalach, restecg, chol | age, heartdisease, fbs, trestbps)
# (sex _|_ thalach | heartdisease, exang, restecg, chol)
# (sex _|_ thalach, chol | heartdisease, exang, restecg, fbs)
# (sex _|_ thalach, chol | heartdisease, exang, restecg, trestbps)
# (sex _|_ heartdisease, thalach, chol | exang, restecg, trestbps, fbs)
# (sex _|_ thalach, restecg | heartdisease, exang, fbs, chol)
# (sex _|_ thalach, restecg | heartdisease, exang, chol, trestbps)
# (sex _|_ heartdisease, thalach, restecg | exang, fbs, chol, trestbps)
# (sex _|_ thalach, restecg, chol | heartdisease, exang, fbs, trestbps)
# (sex _|_ thalach | heartdisease, restecg, fbs, chol)
# (sex _|_ thalach | heartdisease, restecg, chol, trestbps)
# (sex _|_ heartdisease, thalach | restecg, fbs, chol, trestbps)
# (sex _|_ thalach, chol | heartdisease, restecg, fbs, trestbps)
# (sex _|_ thalach, restecg | heartdisease, fbs, chol, trestbps)
# (sex _|_ chol | age, exang, restecg, heartdisease, thalach)
# (sex _|_ heartdisease, fbs, chol | age, exang, restecg, thalach, trestbps)
# (sex _|_ restecg | age, exang, chol, heartdisease, thalach)
# (sex _|_ heartdisease, restecg, fbs | age, exang, chol, thalach, trestbps)
# (sex _|_ restecg, chol | age, exang, heartdisease, thalach, fbs)
# (sex _|_ restecg, fbs, chol | age, exang, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, restecg, chol | age, exang, thalach, fbs, trestbps)
# (sex _|_ heartdisease, fbs | age, restecg, chol, thalach, trestbps)
# (sex _|_ chol | age, restecg, heartdisease, thalach, fbs)
# (sex _|_ fbs, chol | age, restecg, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, chol | age, restecg, thalach, fbs, trestbps)
# (sex _|_ restecg | age, chol, heartdisease, thalach, fbs)
# (sex _|_ restecg, fbs | age, chol, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, restecg | age, chol, thalach, fbs, trestbps)
# (sex _|_ restecg, chol | age, heartdisease, thalach, fbs, trestbps)
# (sex _|_ chol | thalach, exang, restecg, heartdisease, fbs)
# (sex _|_ chol | thalach, exang, restecg, heartdisease, trestbps)
# (sex _|_ heartdisease, chol | exang, restecg, thalach, fbs, trestbps)
# (sex _|_ restecg | thalach, exang, chol, heartdisease, fbs)
# (sex _|_ restecg | thalach, exang, chol, heartdisease, trestbps)
# (sex _|_ heartdisease, restecg | exang, chol, thalach, fbs, trestbps)
# (sex _|_ restecg, chol | thalach, exang, heartdisease, fbs, trestbps)
# (sex _|_ heartdisease | restecg, chol, thalach, fbs, trestbps)
# (sex _|_ chol | thalach, restecg, heartdisease, fbs, trestbps)
# (sex _|_ restecg | thalach, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | age, exang, restecg, chol, heartdisease)
# (sex _|_ heartdisease, fbs, thalach | age, exang, restecg, chol, trestbps)
# (sex _|_ thalach, chol | age, exang, restecg, heartdisease, fbs)
# (sex _|_ thalach, fbs, chol | age, exang, restecg, heartdisease, trestbps)
# (sex _|_ heartdisease, chol, thalach | age, exang, restecg, fbs, trestbps)
# (sex _|_ thalach, restecg | age, exang, chol, heartdisease, fbs)
# (sex _|_ thalach, restecg, fbs | age, exang, chol, heartdisease, trestbps)
# (sex _|_ heartdisease, restecg, thalach | age, exang, chol, fbs, trestbps)
# (sex _|_ thalach, restecg, chol | age, exang, heartdisease, fbs, trestbps)
# (sex _|_ thalach | age, restecg, chol, heartdisease, fbs)
# (sex _|_ thalach, fbs | age, restecg, chol, heartdisease, trestbps)
# (sex _|_ heartdisease, thalach | age, restecg, chol, fbs, trestbps)
# (sex _|_ thalach, chol | age, restecg, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg | age, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | exang, restecg, chol, heartdisease, fbs)
# (sex _|_ thalach | exang, restecg, chol, heartdisease, trestbps)
# (sex _|_ heartdisease, thalach | exang, restecg, chol, fbs, trestbps)
# (sex _|_ thalach, chol | exang, restecg, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | restecg, chol, heartdisease, fbs, trestbps)
# (sex _|_ heartdisease, fbs | age, exang, restecg, chol, thalach, trestbps)
# (sex _|_ chol | age, exang, restecg, heartdisease, thalach, fbs)
# (sex _|_ fbs, chol | age, exang, restecg, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, chol | age, exang, restecg, thalach, fbs, trestbps)
# (sex _|_ restecg | age, exang, chol, heartdisease, thalach, fbs)
# (sex _|_ restecg, fbs | age, exang, chol, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease, restecg | age, exang, chol, thalach, fbs, trestbps)
# (sex _|_ restecg, chol | age, exang, heartdisease, thalach, fbs, trestbps)
# (sex _|_ fbs | age, restecg, chol, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease | age, restecg, chol, thalach, fbs, trestbps)
# (sex _|_ chol | age, restecg, heartdisease, thalach, fbs, trestbps)
# (sex _|_ restecg | age, chol, heartdisease, thalach, fbs, trestbps)
# (sex _|_ heartdisease | exang, restecg, chol, thalach, fbs, trestbps)
# (sex _|_ chol | thalach, exang, restecg, heartdisease, fbs, trestbps)
# (sex _|_ restecg | thalach, exang, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | age, exang, restecg, chol, heartdisease, fbs)
# (sex _|_ thalach, fbs | age, exang, restecg, chol, heartdisease, trestbps)
# (sex _|_ heartdisease, thalach | age, exang, restecg, chol, fbs, trestbps)
# (sex _|_ thalach, chol | age, exang, restecg, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg | age, exang, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | age, restecg, chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach | exang, restecg, chol, heartdisease, fbs, trestbps)
# (sex _|_ fbs | age, exang, restecg, chol, heartdisease, thalach, trestbps)
# (sex _|_ heartdisease | age, exang, restecg, chol, thalach, fbs, trestbps)
# (sex _|_ chol | age, exang, restecg, heartdisease, thalach, fbs, trestbps)
# (sex _|_ restecg | age, exang, chol, heartdisease, thalach, fbs, trestbps)
# (sex _|_ thalach | age, exang, restecg, chol, heartdisease, fbs, trestbps)
# (exang _|_ age, fbs, sex)
# (exang _|_ age, fbs | sex)
# (exang _|_ fbs, sex | age)
# (exang _|_ thalach, restecg, chol | heartdisease)
# (exang _|_ age, sex | fbs)
# (exang _|_ restecg, chol | heartdisease, thalach)
# (exang _|_ fbs | age, sex)
# (exang _|_ thalach, restecg, chol | heartdisease, sex)
# (exang _|_ age | fbs, sex)
# (exang _|_ thalach, restecg, chol | age, heartdisease)
# (exang _|_ sex | age, fbs)
# (exang _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg)
# (exang _|_ thalach, restecg | heartdisease, chol)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs)
# (exang _|_ thalach, restecg, chol | heartdisease, trestbps)
# (exang _|_ heartdisease, restecg, chol, thalach | fbs, trestbps)
# (exang _|_ restecg, chol | heartdisease, thalach, sex)
# (exang _|_ restecg, chol | age, thalach, heartdisease)
# (exang _|_ heartdisease, restecg, fbs, chol | age, thalach, trestbps)
# (exang _|_ chol | heartdisease, thalach, restecg)
# (exang _|_ restecg | heartdisease, thalach, chol)
# (exang _|_ restecg, chol | heartdisease, thalach, fbs)
# (exang _|_ restecg, chol | heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, restecg, chol | thalach, fbs, trestbps)
# (exang _|_ thalach, restecg, chol | age, heartdisease, sex)
# (exang _|_ restecg, chol, heartdisease, thalach, fbs | age, trestbps, sex)
# (exang _|_ thalach, chol | heartdisease, restecg, sex)
# (exang _|_ thalach, restecg | heartdisease, chol, sex)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs, sex)
# (exang _|_ thalach, restecg, chol | heartdisease, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol, thalach | fbs, trestbps, sex)
# (exang _|_ thalach, chol | age, heartdisease, restecg)
# (exang _|_ heartdisease, thalach, fbs, chol | age, restecg, trestbps)
# (exang _|_ thalach, restecg | age, heartdisease, chol)
# (exang _|_ heartdisease, thalach, restecg, fbs | age, chol, trestbps)
# (exang _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (exang _|_ thalach, restecg, fbs, chol | age, heartdisease, trestbps)
# (exang _|_ heartdisease, thalach, restecg, chol | age, fbs, trestbps)
# (exang _|_ thalach | heartdisease, restecg, chol)
# (exang _|_ thalach, chol | heartdisease, restecg, fbs)
# (exang _|_ thalach, chol | heartdisease, restecg, trestbps)
# (exang _|_ heartdisease, chol, thalach | restecg, fbs, trestbps)
# (exang _|_ thalach, restecg | heartdisease, fbs, chol)
# (exang _|_ thalach, restecg | heartdisease, chol, trestbps)
# (exang _|_ heartdisease, restecg, thalach | fbs, chol, trestbps)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (exang _|_ restecg, chol | age, thalach, heartdisease, sex)
# (exang _|_ heartdisease, restecg, fbs, chol | age, thalach, trestbps, sex)
# (exang _|_ chol | heartdisease, thalach, restecg, sex)
# (exang _|_ restecg | heartdisease, thalach, chol, sex)
# (exang _|_ restecg, chol | heartdisease, thalach, fbs, sex)
# (exang _|_ restecg, chol | heartdisease, thalach, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol | thalach, fbs, trestbps, sex)
# (exang _|_ chol | age, thalach, restecg, heartdisease)
# (exang _|_ heartdisease, fbs, chol | age, thalach, restecg, trestbps)
# (exang _|_ restecg | age, thalach, chol, heartdisease)
# (exang _|_ heartdisease, restecg, fbs | age, thalach, chol, trestbps)
# (exang _|_ restecg, chol | age, thalach, fbs, heartdisease)
# (exang _|_ restecg, fbs, chol | age, thalach, heartdisease, trestbps)
# (exang _|_ heartdisease, restecg, chol | age, thalach, fbs, trestbps)
# (exang _|_ chol | heartdisease, thalach, restecg, fbs)
# (exang _|_ chol | heartdisease, thalach, restecg, trestbps)
# (exang _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (exang _|_ restecg | heartdisease, thalach, fbs, chol)
# (exang _|_ restecg | heartdisease, thalach, chol, trestbps)
# (exang _|_ heartdisease, restecg | thalach, fbs, chol, trestbps)
# (exang _|_ restecg, chol | heartdisease, thalach, fbs, trestbps)
# (exang _|_ thalach, chol | age, heartdisease, restecg, sex)
# (exang _|_ heartdisease, fbs, chol, thalach | age, restecg, trestbps, sex)
# (exang _|_ thalach, restecg | age, heartdisease, chol, sex)
# (exang _|_ heartdisease, restecg, fbs, thalach | age, chol, trestbps, sex)
# (exang _|_ thalach, restecg, chol | age, heartdisease, fbs, sex)
# (exang _|_ thalach, restecg, fbs, chol | age, heartdisease, trestbps, sex)
# (exang _|_ heartdisease, restecg, chol, thalach | age, fbs, trestbps, sex)
# (exang _|_ thalach | heartdisease, restecg, chol, sex)
# (exang _|_ thalach, chol | heartdisease, restecg, fbs, sex)
# (exang _|_ thalach, chol | heartdisease, restecg, trestbps, sex)
# (exang _|_ heartdisease, thalach, chol | restecg, fbs, trestbps, sex)
# (exang _|_ thalach, restecg | heartdisease, fbs, chol, sex)
# (exang _|_ thalach, restecg | heartdisease, chol, trestbps, sex)
# (exang _|_ heartdisease, thalach, restecg | fbs, chol, trestbps, sex)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs, trestbps, sex)
# (exang _|_ thalach | age, heartdisease, restecg, chol)
# (exang _|_ heartdisease, fbs, thalach | age, restecg, chol, trestbps)
# (exang _|_ thalach, chol | age, heartdisease, restecg, fbs)
# (exang _|_ thalach, fbs, chol | age, heartdisease, restecg, trestbps)
# (exang _|_ heartdisease, chol, thalach | age, restecg, fbs, trestbps)
# (exang _|_ thalach, restecg | age, heartdisease, fbs, chol)
# (exang _|_ thalach, restecg, fbs | age, heartdisease, chol, trestbps)
# (exang _|_ heartdisease, restecg, thalach | age, fbs, chol, trestbps)
# (exang _|_ thalach, restecg, chol | age, heartdisease, fbs, trestbps)
# (exang _|_ thalach | heartdisease, restecg, fbs, chol)
# (exang _|_ thalach | heartdisease, restecg, chol, trestbps)
# (exang _|_ heartdisease, thalach | restecg, fbs, chol, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg, fbs, trestbps)
# (exang _|_ thalach, restecg | heartdisease, fbs, chol, trestbps)
# (exang _|_ chol | sex, age, restecg, heartdisease, thalach)
# (exang _|_ heartdisease, fbs, chol | sex, age, restecg, thalach, trestbps)
# (exang _|_ restecg | sex, age, chol, heartdisease, thalach)
# (exang _|_ heartdisease, restecg, fbs | sex, age, chol, thalach, trestbps)
# (exang _|_ restecg, chol | sex, age, heartdisease, thalach, fbs)
# (exang _|_ restecg, fbs, chol | sex, age, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, restecg, chol | sex, age, thalach, fbs, trestbps)
# (exang _|_ chol | thalach, sex, restecg, heartdisease, fbs)
# (exang _|_ chol | thalach, sex, restecg, heartdisease, trestbps)
# (exang _|_ heartdisease, chol | sex, restecg, thalach, fbs, trestbps)
# (exang _|_ restecg | thalach, sex, chol, heartdisease, fbs)
# (exang _|_ restecg | thalach, sex, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, restecg | sex, chol, thalach, fbs, trestbps)
# (exang _|_ restecg, chol | thalach, sex, heartdisease, fbs, trestbps)
# (exang _|_ heartdisease, fbs | age, restecg, chol, thalach, trestbps)
# (exang _|_ chol | age, restecg, heartdisease, thalach, fbs)
# (exang _|_ fbs, chol | age, restecg, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, chol | age, restecg, thalach, fbs, trestbps)
# (exang _|_ restecg | age, chol, heartdisease, thalach, fbs)
# (exang _|_ restecg, fbs | age, chol, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, restecg | age, chol, thalach, fbs, trestbps)
# (exang _|_ restecg, chol | age, heartdisease, thalach, fbs, trestbps)
# (exang _|_ heartdisease | restecg, chol, thalach, fbs, trestbps)
# (exang _|_ chol | thalach, restecg, heartdisease, fbs, trestbps)
# (exang _|_ restecg | thalach, chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach | sex, age, restecg, chol, heartdisease)
# (exang _|_ heartdisease, fbs, thalach | sex, age, restecg, chol, trestbps)
# (exang _|_ thalach, chol | sex, age, restecg, heartdisease, fbs)
# (exang _|_ thalach, fbs, chol | sex, age, restecg, heartdisease, trestbps)
# (exang _|_ heartdisease, chol, thalach | sex, age, restecg, fbs, trestbps)
# (exang _|_ thalach, restecg | sex, age, chol, heartdisease, fbs)
# (exang _|_ thalach, restecg, fbs | sex, age, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, restecg, thalach | sex, age, chol, fbs, trestbps)
# (exang _|_ thalach, restecg, chol | sex, age, heartdisease, fbs, trestbps)
# (exang _|_ thalach | sex, restecg, chol, heartdisease, fbs)
# (exang _|_ thalach | sex, restecg, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, thalach | sex, restecg, chol, fbs, trestbps)
# (exang _|_ thalach, chol | sex, restecg, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg | sex, chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach | age, restecg, chol, heartdisease, fbs)
# (exang _|_ thalach, fbs | age, restecg, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, thalach | age, restecg, chol, fbs, trestbps)
# (exang _|_ thalach, chol | age, restecg, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg | age, chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach | restecg, chol, heartdisease, fbs, trestbps)
# (exang _|_ heartdisease, fbs | sex, age, restecg, chol, thalach, trestbps)
# (exang _|_ chol | sex, age, restecg, heartdisease, thalach, fbs)
# (exang _|_ fbs, chol | sex, age, restecg, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, chol | sex, age, restecg, thalach, fbs, trestbps)
# (exang _|_ restecg | sex, age, chol, heartdisease, thalach, fbs)
# (exang _|_ restecg, fbs | sex, age, chol, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease, restecg | sex, age, chol, thalach, fbs, trestbps)
# (exang _|_ restecg, chol | sex, age, heartdisease, thalach, fbs, trestbps)
# (exang _|_ heartdisease | sex, restecg, chol, thalach, fbs, trestbps)
# (exang _|_ chol | thalach, sex, restecg, heartdisease, fbs, trestbps)
# (exang _|_ restecg | thalach, sex, chol, heartdisease, fbs, trestbps)
# (exang _|_ fbs | age, restecg, chol, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease | age, restecg, chol, thalach, fbs, trestbps)
# (exang _|_ chol | age, restecg, heartdisease, thalach, fbs, trestbps)
# (exang _|_ restecg | age, chol, heartdisease, thalach, fbs, trestbps)
# (exang _|_ thalach | sex, age, restecg, chol, heartdisease, fbs)
# (exang _|_ thalach, fbs | sex, age, restecg, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, thalach | sex, age, restecg, chol, fbs, trestbps)
# (exang _|_ thalach, chol | sex, age, restecg, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg | sex, age, chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach | sex, restecg, chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach | age, restecg, chol, heartdisease, fbs, trestbps)
# (exang _|_ fbs | sex, age, restecg, chol, heartdisease, thalach, trestbps)
# (exang _|_ heartdisease | sex, age, restecg, chol, thalach, fbs, trestbps)
# (exang _|_ chol | sex, age, restecg, heartdisease, thalach, fbs, trestbps)
# (exang _|_ restecg | sex, age, chol, heartdisease, thalach, fbs, trestbps)
# (exang _|_ thalach | sex, age, restecg, chol, heartdisease, fbs, trestbps)
# (heartdisease _|_ exang, sex | age, trestbps)
# (heartdisease _|_ age, exang, sex | fbs, trestbps)
# (heartdisease _|_ exang, sex | age, thalach, trestbps)
# (heartdisease _|_ age, exang, sex | thalach, fbs, trestbps)
# (heartdisease _|_ exang | age, trestbps, sex)
# (heartdisease _|_ age, exang | fbs, trestbps, sex)
# (heartdisease _|_ sex | age, exang, trestbps)
# (heartdisease _|_ exang, sex | age, restecg, trestbps)
# (heartdisease _|_ exang, sex | age, chol, trestbps)
# (heartdisease _|_ exang, sex | age, fbs, trestbps)
# (heartdisease _|_ age, sex | exang, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | restecg, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | fbs, chol, trestbps)
# (heartdisease _|_ exang | age, thalach, trestbps, sex)
# (heartdisease _|_ age, exang | thalach, fbs, trestbps, sex)
# (heartdisease _|_ sex | age, thalach, exang, trestbps)
# (heartdisease _|_ exang, sex | age, thalach, restecg, trestbps)
# (heartdisease _|_ exang, sex | age, thalach, chol, trestbps)
# (heartdisease _|_ exang, sex | age, thalach, fbs, trestbps)
# (heartdisease _|_ age, sex | thalach, exang, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | thalach, restecg, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | thalach, fbs, chol, trestbps)
# (heartdisease _|_ exang | age, restecg, trestbps, sex)
# (heartdisease _|_ exang | age, chol, trestbps, sex)
# ...
# (thalach _|_ age | sex, exang, restecg, fbs, trestbps)
# (thalach _|_ age, restecg, trestbps | sex, exang, chol, heartdisease, fbs)
# (thalach _|_ age, restecg, fbs | sex, exang, chol, heartdisease, trestbps)
# (thalach _|_ age | sex, exang, chol, fbs, trestbps)
# (thalach _|_ age, restecg, chol | sex, exang, heartdisease, fbs, trestbps)
# (thalach _|_ age, exang, trestbps | sex, restecg, chol, heartdisease, fbs)
# (thalach _|_ age, exang, fbs | sex, restecg, chol, heartdisease, trestbps)
# (thalach _|_ age, exang | sex, restecg, chol, fbs, trestbps)
# (thalach _|_ age, exang, chol | sex, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ age, exang, restecg | sex, chol, heartdisease, fbs, trestbps)
# (thalach _|_ fbs, trestbps, sex | age, exang, restecg, chol, heartdisease)
# (thalach _|_ sex | age, exang, restecg, chol, trestbps)
# (thalach _|_ chol, trestbps, sex | age, exang, restecg, heartdisease, fbs)
# (thalach _|_ fbs, chol, sex | age, exang, restecg, heartdisease, trestbps)
# (thalach _|_ sex | age, exang, restecg, fbs, trestbps)
# (thalach _|_ restecg, trestbps, sex | age, exang, chol, heartdisease, fbs)
# (thalach _|_ restecg, fbs, sex | age, exang, chol, heartdisease, trestbps)
# (thalach _|_ sex | age, exang, chol, fbs, trestbps)
# (thalach _|_ restecg, chol, sex | age, exang, heartdisease, fbs, trestbps)
# (thalach _|_ exang, trestbps, sex | age, restecg, chol, heartdisease, fbs)
# (thalach _|_ exang, fbs, sex | age, restecg, chol, heartdisease, trestbps)
# (thalach _|_ exang, sex | age, restecg, chol, fbs, trestbps)
# (thalach _|_ exang, chol, sex | age, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ exang, restecg, sex | age, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age, trestbps, sex | exang, restecg, chol, heartdisease, fbs)
# (thalach _|_ age, fbs, sex | exang, restecg, chol, heartdisease, trestbps)
# (thalach _|_ age, sex | exang, restecg, chol, fbs, trestbps)
# (thalach _|_ age, chol, sex | exang, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ age, restecg, sex | exang, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age, exang, sex | restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ fbs, trestbps | sex, age, exang, restecg, chol, heartdisease)
# (thalach _|_ chol, trestbps | sex, age, exang, restecg, heartdisease, fbs)
# (thalach _|_ fbs, chol | sex, age, exang, restecg, heartdisease, trestbps)
# (thalach _|_ restecg, trestbps | sex, age, exang, chol, heartdisease, fbs)
# (thalach _|_ restecg, fbs | sex, age, exang, chol, heartdisease, trestbps)
# (thalach _|_ restecg, chol | sex, age, exang, heartdisease, fbs, trestbps)
# (thalach _|_ exang, trestbps | sex, age, restecg, chol, heartdisease, fbs)
# (thalach _|_ exang, fbs | sex, age, restecg, chol, heartdisease, trestbps)
# (thalach _|_ exang | sex, age, restecg, chol, fbs, trestbps)
# (thalach _|_ exang, chol | sex, age, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ exang, restecg | sex, age, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age, trestbps | sex, exang, restecg, chol, heartdisease, fbs)
# (thalach _|_ age, fbs | sex, exang, restecg, chol, heartdisease, trestbps)
# (thalach _|_ age | sex, exang, restecg, chol, fbs, trestbps)
# (thalach _|_ age, chol | sex, exang, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ age, restecg | sex, exang, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age, exang | sex, restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ trestbps, sex | age, exang, restecg, chol, heartdisease, fbs)
# (thalach _|_ fbs, sex | age, exang, restecg, chol, heartdisease, trestbps)
# (thalach _|_ sex | age, exang, restecg, chol, fbs, trestbps)
# (thalach _|_ chol, sex | age, exang, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ restecg, sex | age, exang, chol, heartdisease, fbs, trestbps)
# (thalach _|_ exang, sex | age, restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age, sex | exang, restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ trestbps | sex, age, exang, restecg, chol, heartdisease, fbs)
# (thalach _|_ fbs | sex, age, exang, restecg, chol, heartdisease, trestbps)
# (thalach _|_ chol | sex, age, exang, restecg, heartdisease, fbs, trestbps)
# (thalach _|_ restecg | sex, age, exang, chol, heartdisease, fbs, trestbps)
# (thalach _|_ exang | sex, age, restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ age | sex, exang, restecg, chol, heartdisease, fbs, trestbps)
# (thalach _|_ sex | age, exang, restecg, chol, heartdisease, fbs, trestbps)
# (chol _|_ restecg, sex, age, thalach, exang, fbs, trestbps | heartdisease)
# (chol _|_ restecg, sex, age, exang, fbs, trestbps | heartdisease, thalach)
# (chol _|_ restecg, age, thalach, exang, fbs, trestbps | heartdisease, sex)
# (chol _|_ restecg, sex, thalach, exang, fbs, trestbps | age, heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ restecg, sex, age, thalach, fbs, trestbps | heartdisease, exang)
# (chol _|_ sex, age, thalach, exang, fbs, trestbps | heartdisease, restecg)
# (chol _|_ restecg, sex, age, thalach, exang, trestbps | heartdisease, fbs)
# (chol _|_ restecg, sex, age, thalach, exang, fbs | heartdisease, trestbps)
# (chol _|_ age, exang, sex | fbs, trestbps)
# (chol _|_ restecg, age, exang, fbs, trestbps | heartdisease, thalach, sex)
# (chol _|_ restecg, sex, exang, fbs, trestbps | age, thalach, heartdisease)
# (chol _|_ exang, sex | age, thalach, trestbps)
# (chol _|_ restecg, sex, age, fbs, trestbps | heartdisease, thalach, exang)
# (chol _|_ sex, age, exang, fbs, trestbps | heartdisease, thalach, restecg)
# (chol _|_ restecg, sex, age, exang, trestbps | heartdisease, thalach, fbs)
# (chol _|_ restecg, sex, age, exang, fbs | heartdisease, thalach, trestbps)
# (chol _|_ age, exang, sex | thalach, fbs, trestbps)
# (chol _|_ restecg, thalach, exang, fbs, trestbps | age, heartdisease, sex)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ restecg, age, thalach, fbs, trestbps | heartdisease, exang, sex)
# (chol _|_ age, thalach, exang, fbs, trestbps | heartdisease, restecg, sex)
# (chol _|_ restecg, age, thalach, exang, trestbps | heartdisease, fbs, sex)
# (chol _|_ restecg, age, thalach, exang, fbs | heartdisease, trestbps, sex)
# (chol _|_ age, exang | fbs, trestbps, sex)
# (chol _|_ restecg, sex, thalach, fbs, trestbps | age, heartdisease, exang)
# (chol _|_ sex | age, exang, trestbps)
# (chol _|_ sex, thalach, exang, fbs, trestbps | age, heartdisease, restecg)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ restecg, sex, thalach, exang, trestbps | age, heartdisease, fbs)
# (chol _|_ restecg, sex, thalach, exang, fbs | age, heartdisease, trestbps)
# (chol _|_ exang, sex | age, fbs, trestbps)
# (chol _|_ sex, age, thalach, fbs, trestbps | heartdisease, exang, restecg)
# (chol _|_ restecg, sex, age, thalach, trestbps | heartdisease, exang, fbs)
# (chol _|_ restecg, sex, age, thalach, fbs | heartdisease, exang, trestbps)
# (chol _|_ age, sex | exang, fbs, trestbps)
# (chol _|_ sex, age, thalach, exang, trestbps | heartdisease, restecg, fbs)
# (chol _|_ sex, age, thalach, exang, fbs | heartdisease, restecg, trestbps)
# (chol _|_ age, exang, sex | restecg, fbs, trestbps)
# (chol _|_ restecg, sex, age, thalach, exang | heartdisease, fbs, trestbps)
# (chol _|_ fbs, exang, restecg, trestbps | age, thalach, heartdisease, sex)
# (chol _|_ exang | age, thalach, trestbps, sex)
# (chol _|_ age, restecg, fbs, trestbps | heartdisease, thalach, exang, sex)
# (chol _|_ age, exang, fbs, trestbps | heartdisease, thalach, restecg, sex)
# (chol _|_ age, exang, restecg, trestbps | heartdisease, thalach, fbs, sex)
# (chol _|_ age, exang, restecg, fbs | heartdisease, thalach, trestbps, sex)
# (chol _|_ age, exang | thalach, fbs, trestbps, sex)
# (chol _|_ restecg, fbs, trestbps, sex | age, thalach, exang, heartdisease)
# (chol _|_ sex | age, thalach, exang, trestbps)
# (chol _|_ exang, fbs, trestbps, sex | age, thalach, restecg, heartdisease)
# (chol _|_ exang, sex | age, thalach, restecg, trestbps)
# (chol _|_ exang, restecg, trestbps, sex | age, thalach, fbs, heartdisease)
# (chol _|_ exang, restecg, fbs, sex | age, thalach, heartdisease, trestbps)
# (chol _|_ exang, sex | age, thalach, fbs, trestbps)
# (chol _|_ age, fbs, trestbps, sex | heartdisease, thalach, exang, restecg)
# (chol _|_ age, restecg, trestbps, sex | heartdisease, thalach, exang, fbs)
# (chol _|_ age, restecg, fbs, sex | heartdisease, thalach, exang, trestbps)
# (chol _|_ age, sex | thalach, exang, fbs, trestbps)
# (chol _|_ age, exang, trestbps, sex | heartdisease, thalach, restecg, fbs)
# (chol _|_ age, exang, fbs, sex | heartdisease, thalach, restecg, trestbps)
# (chol _|_ age, exang, sex | thalach, restecg, fbs, trestbps)
# (chol _|_ age, exang, restecg, sex | heartdisease, thalach, fbs, trestbps)
# (chol _|_ thalach, restecg, fbs, trestbps | age, heartdisease, exang, sex)
# (chol _|_ thalach, exang, fbs, trestbps | age, heartdisease, restecg, sex)
# (chol _|_ exang | age, restecg, trestbps, sex)
# (chol _|_ thalach, exang, restecg, trestbps | age, heartdisease, fbs, sex)
# (chol _|_ thalach, exang, restecg, fbs | age, heartdisease, trestbps, sex)
# (chol _|_ exang | age, fbs, trestbps, sex)
# (chol _|_ age, thalach, fbs, trestbps | heartdisease, exang, restecg, sex)
# (chol _|_ age, thalach, restecg, trestbps | heartdisease, exang, fbs, sex)
# (chol _|_ age, thalach, restecg, fbs | heartdisease, exang, trestbps, sex)
# (chol _|_ age | exang, fbs, trestbps, sex)
# (chol _|_ age, thalach, exang, trestbps | heartdisease, restecg, fbs, sex)
# (chol _|_ age, thalach, exang, fbs | heartdisease, restecg, trestbps, sex)
# (chol _|_ age, exang | restecg, fbs, trestbps, sex)
# (chol _|_ age, thalach, exang, restecg | heartdisease, fbs, trestbps, sex)
# (chol _|_ thalach, fbs, trestbps, sex | age, heartdisease, exang, restecg)
# (chol _|_ sex | age, exang, restecg, trestbps)
# (chol _|_ thalach, restecg, trestbps, sex | age, heartdisease, exang, fbs)
# (chol _|_ thalach, restecg, fbs, sex | age, heartdisease, exang, trestbps)
# (chol _|_ sex | age, exang, fbs, trestbps)
# (chol _|_ thalach, exang, trestbps, sex | age, heartdisease, restecg, fbs)
# (chol _|_ thalach, exang, fbs, sex | age, heartdisease, restecg, trestbps)
# (chol _|_ exang, sex | age, restecg, fbs, trestbps)
# (chol _|_ thalach, exang, restecg, sex | age, heartdisease, fbs, trestbps)
# (chol _|_ age, thalach, trestbps, sex | heartdisease, exang, restecg, fbs)
# (chol _|_ age, thalach, fbs, sex | heartdisease, exang, restecg, trestbps)
# (chol _|_ age, sex | exang, restecg, trestbps, fbs)
# (chol _|_ age, thalach, restecg, sex | heartdisease, exang, fbs, trestbps)
# (chol _|_ age, thalach, exang, sex | heartdisease, restecg, fbs, trestbps)
# (chol _|_ restecg, fbs, trestbps | sex, age, exang, heartdisease, thalach)
# (chol _|_ exang, fbs, trestbps | sex, age, restecg, heartdisease, thalach)
# (chol _|_ exang | sex, age, restecg, thalach, trestbps)
# (chol _|_ exang, restecg, trestbps | sex, age, heartdisease, thalach, fbs)
# (chol _|_ exang, restecg, fbs | sex, age, heartdisease, thalach, trestbps)
# (chol _|_ exang | sex, age, thalach, fbs, trestbps)
# (chol _|_ age, fbs, trestbps | thalach, sex, exang, restecg, heartdisease)
# (chol _|_ age, restecg, trestbps | thalach, sex, exang, heartdisease, fbs)
# (chol _|_ age, restecg, fbs | thalach, sex, exang, heartdisease, trestbps)
# (chol _|_ age | sex, exang, thalach, fbs, trestbps)
# (chol _|_ age, exang, trestbps | thalach, sex, restecg, heartdisease, fbs)
# (chol _|_ age, exang, fbs | thalach, sex, restecg, heartdisease, trestbps)
# (chol _|_ age, exang | sex, restecg, thalach, fbs, trestbps)
# (chol _|_ age, exang, restecg | thalach, sex, heartdisease, fbs, trestbps)
# (chol _|_ fbs, trestbps, sex | age, exang, restecg, heartdisease, thalach)
# (chol _|_ sex | age, exang, restecg, thalach, trestbps)
# (chol _|_ restecg, trestbps, sex | age, exang, heartdisease, thalach, fbs)
# (chol _|_ restecg, fbs, sex | age, exang, heartdisease, thalach, trestbps)
# (chol _|_ sex | age, exang, thalach, fbs, trestbps)
# (chol _|_ exang, trestbps, sex | age, restecg, heartdisease, thalach, fbs)
# (chol _|_ exang, fbs, sex | age, restecg, heartdisease, thalach, trestbps)
# (chol _|_ exang, sex | age, restecg, thalach, fbs, trestbps)
# (chol _|_ exang, restecg, sex | age, heartdisease, thalach, fbs, trestbps)
# (chol _|_ age, trestbps, sex | thalach, exang, restecg, heartdisease, fbs)
# (chol _|_ age, fbs, sex | thalach, exang, restecg, heartdisease, trestbps)
# (chol _|_ age, sex | exang, restecg, thalach, fbs, trestbps)
# (chol _|_ age, restecg, sex | thalach, exang, heartdisease, fbs, trestbps)
# (chol _|_ age, exang, sex | thalach, restecg, heartdisease, fbs, trestbps)
# (chol _|_ thalach, fbs, trestbps | sex, age, exang, restecg, heartdisease)
# (chol _|_ thalach, restecg, trestbps | sex, age, exang, heartdisease, fbs)
# (chol _|_ thalach, restecg, fbs | sex, age, exang, heartdisease, trestbps)
# (chol _|_ thalach, exang, trestbps | sex, age, restecg, heartdisease, fbs)
# (chol _|_ thalach, exang, fbs | sex, age, restecg, heartdisease, trestbps)
# (chol _|_ exang | sex, age, restecg, fbs, trestbps)
# (chol _|_ thalach, exang, restecg | sex, age, heartdisease, fbs, trestbps)
# (chol _|_ age, thalach, trestbps | sex, exang, restecg, heartdisease, fbs)
# (chol _|_ age, thalach, fbs | sex, exang, restecg, heartdisease, trestbps)
# (chol _|_ age | sex, exang, restecg, fbs, trestbps)
# (chol _|_ age, thalach, restecg | sex, exang, heartdisease, fbs, trestbps)
# (chol _|_ age, thalach, exang | sex, restecg, heartdisease, fbs, trestbps)
# (chol _|_ thalach, trestbps, sex | age, exang, restecg, heartdisease, fbs)
# (chol _|_ thalach, fbs, sex | age, exang, restecg, heartdisease, trestbps)
# (chol _|_ sex | age, exang, restecg, fbs, trestbps)
# (chol _|_ thalach, restecg, sex | age, exang, heartdisease, fbs, trestbps)
# (chol _|_ thalach, exang, sex | age, restecg, heartdisease, fbs, trestbps)
# (chol _|_ age, thalach, sex | exang, restecg, heartdisease, fbs, trestbps)
# (chol _|_ fbs, trestbps | sex, age, exang, restecg, heartdisease, thalach)
# (chol _|_ restecg, trestbps | sex, age, exang, heartdisease, thalach, fbs)
# (chol _|_ restecg, fbs | sex, age, exang, heartdisease, thalach, trestbps)
# (chol _|_ exang, trestbps | sex, age, restecg, heartdisease, thalach, fbs)
# (chol _|_ exang, fbs | sex, age, restecg, heartdisease, thalach, trestbps)
# (chol _|_ exang | sex, age, restecg, thalach, fbs, trestbps)
# (chol _|_ exang, restecg | sex, age, heartdisease, thalach, fbs, trestbps)
# (chol _|_ age, trestbps | thalach, sex, exang, restecg, heartdisease, fbs)
# (chol _|_ age, fbs | thalach, sex, exang, restecg, heartdisease, trestbps)
# (chol _|_ age | sex, exang, restecg, thalach, fbs, trestbps)
# (chol _|_ age, restecg | thalach, sex, exang, heartdisease, fbs, trestbps)
# (chol _|_ age, exang | thalach, sex, restecg, heartdisease, fbs, trestbps)
# (chol _|_ trestbps, sex | age, exang, restecg, heartdisease, thalach, fbs)
# (chol _|_ fbs, sex | age, exang, restecg, heartdisease, thalach, trestbps)
# (chol _|_ sex | age, exang, restecg, thalach, fbs, trestbps)
# (chol _|_ restecg, sex | age, exang, heartdisease, thalach, fbs, trestbps)
# (chol _|_ exang, sex | age, restecg, heartdisease, thalach, fbs, trestbps)
# (chol _|_ age, sex | thalach, exang, restecg, heartdisease, fbs, trestbps)
# (chol _|_ thalach, trestbps | sex, age, exang, restecg, heartdisease, fbs)
# (chol _|_ thalach, fbs | sex, age, exang, restecg, heartdisease, trestbps)
# (chol _|_ thalach, restecg | sex, age, exang, heartdisease, fbs, trestbps)
# (chol _|_ thalach, exang | sex, age, restecg, heartdisease, fbs, trestbps)
# (chol _|_ age, thalach | sex, exang, restecg, heartdisease, fbs, trestbps)
# (chol _|_ thalach, sex | age, exang, restecg, heartdisease, fbs, trestbps)
# (chol _|_ trestbps | sex, age, exang, restecg, heartdisease, thalach, fbs)
# (chol _|_ fbs | sex, age, exang, restecg, heartdisease, thalach, trestbps)
# (chol _|_ restecg | sex, age, exang, heartdisease, thalach, fbs, trestbps)
# (chol _|_ exang | sex, age, restecg, heartdisease, thalach, fbs, trestbps)
# (chol _|_ age | thalach, sex, exang, restecg, heartdisease, fbs, trestbps)
# (chol _|_ sex | age, exang, restecg, heartdisease, thalach, fbs, trestbps)
# (chol _|_ thalach | sex, age, exang, restecg, heartdisease, fbs, trestbps)

# %%
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛
# c:\users\harshith\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]
# c:\users\harshith\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
